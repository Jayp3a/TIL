# %% [markdown]
# ## Linear Regression Model

# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import os
import pandas as pd
import numpy as np

# %%
# Set the working directory to the folder where your data is stored
os.chdir("C:\\Users\lickfett-john\Documents\Python Scripts\small_sample")
# See what files are in the folder.
os.listdir()
# Out:
# ['results_train-test_LRM.csv', 'test.xlsx', 'train.xlsx', 'validate.xlsx']

# %%
# Read the training data
train = pd.read_excel("train.xlsx", header=0, \
                    delimiter="\t", quoting=3)

#   "header=0" indicates that the first line of the file contains column names, 
#   "delimiter=\t" indicates that the fields are separated by tabs,
#   quoting=3 tells Python to ignore doubled quotes, otherwise you may encounter errors trying to read the file.

# %%
# Import BeautifulSoup into your workspace
import bs4
from bs4 import BeautifulSoup             
import nltk, re
from nltk.corpus import stopwords # Import the stop word list

# %%
def MM_to_words( raw_MM ):
    # Function to convert a raw CMS MM to a string of words
    # The input is a single string (a raw MM text), and 
    # the output is a single string (a preprocessed MM text)
    #
    # 1. Remove HTML
    MM_text = BeautifulSoup(raw_MM,"lxml").get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z,4,5,&,-]", " ", MM_text)
    #letters_only = re.sub("[^a-zA-Z,4,5,&,-]", " ", MM_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #    a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #meaningful_words = [w for w in words]  #If you don't want stops, use this instead.
    #
    # 6. Join the words back into one string separated by space, 
    #    to make the output easier to use in our Bag of Words,
    #    then return the result. 
    return( " ".join( meaningful_words ))

# %%
# Now let's loop through and clean all of the training set at once

# Get the number of MMs based on the dataframe column size
num_MM = train["Visible Text"].size

# Initialize an empty list to hold the clean MMs
clean_train_MM = []

# Loop over each MM; create an index i that goes from 0 to the length
# of theMM list 
for i in range( 0, num_MM ):
    # Call our function for each one, and add the result to the list of
    # clean MMs
    clean_train_MM.append( MM_to_words( train["Visible Text"][i] ) )

# This next bit is optional, and it will give you status updates for every 1,000 rows.
print ("Cleaning and parsing the training set CMS MMs...\n")
clean_train_MM = []
for i in range( 0, num_MM ):
    # If the index is evenly divisible by 100, print a message
    if( (i+1)%100 == 0 ):
        print ("MM %d of %d\n" % ( i+1, num_MM ))                                                                    
    clean_train_MM.append( MM_to_words( train["Visible Text"][i] ))
# Out:
# Cleaning and parsing the training set CMS MMs...
#
# MM 100 of 127

# %% [markdown]
# ### Bag of Words and TF-IDF Frequencies

# %%
print ("Creating the bag of words...\n")

import sklearn
# If you are using Anaconda, Sci-Kit Learn should already be installed. Otherwise you will have to install it.
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             ngram_range=(1, 6),
                             max_features = 9750) # This limits to the 10,000 most frequent words

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
vtrain_data_features = vectorizer.fit_transform(clean_train_MM)

# Numpy arrays are easy to work with, so convert the result to an \

# array
train_data_features = vtrain_data_features.toarray()

# NOTE: CountVectorizer comes with its own options to automatically do preprocessing,
# tokenization, and stop word removal -- for each of these, instead of specifying "None",
# we could have used a built-in method or specified our own function to use.
# However, we wanted to write our own function for data cleaning in this tutorial 
# to show you how it's done step by step.
# Out:
# Creating the bag of words...

# %%
# Now let's import the Python package named scikit-learn, which has a TF-IDF vectorizer
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
### This step is optional ###
# Instead of normal countvectors, we can try using TF-IDF vectors
##TF-IDF stands for “term frequency / inverse document frequency” and is a method 
##for emphasizing words that occur frequently in a given document, while at the same time de-emphasising words that occur frequently in many documents.

TFvectorizer = TfidfVectorizer(#decode_error=u'strict',
                             #strip_accents=None, 
                             #lowercase=True,
                             #preprocessor=None,
                             #tokenizer=None,
                             #analyzer=u'word',
                             #stop_words=None,
                             #token_pattern=u'(?u)\b\w\w+\b',
                             ngram_range=(1, 6),
                             #max_df=1.0,
                             #min_df=1,
                             max_features=9750,
                             #vocabulary=vocab,
                             binary=False,
                             norm=u'l2',
                             use_idf=True,
                             smooth_idf=True,
                             sublinear_tf=False)

train_data_features = TFvectorizer.fit_transform(clean_train_MM)
trainpredictors=train_data_features.toarray()

# %% [markdown]
# ## Linear Regression Model

# %%
# We will import the linear regression model from scikit-learn
from sklearn.linear_model import LinearRegression

# %%
# Here we specify the parameters of the model
Lmodel = LinearRegression(fit_intercept=True,
                          normalize=False,
                          copy_X=True,
                          n_jobs=1)

# This fits the linear regression model to the training dataset
Lmodel = Lmodel.fit( train_data_features, train["page_MM"] )

# %%
###Import the test data###
# Note that when we use the Bag of Words for the test set we only call "transform", 
# not "fit_transform" as we did for the training set. 
# In machine learning, you shouldn't use the test set to fit your model, 
# otherwise you run the risk of overfitting. 
# For this reason, we keep the test set off-limits until we are ready to make predictions.

# Read the test data
test = pd.read_excel("population_dataset_11.7.16.xlsx", header=0, delimiter="\t", \
                   quoting=3 )

# %%
# Create an empty list and append the clean MMs one by one
num_MM = len(test["Visible Text"])
clean_test_MM = [] 

print ("Cleaning and parsing the test set MMs...\n")
for i in range(0,num_MM):
    if( (i+1) % 100 == 0 ):
        print ("CMS MM %d of %d\n" % (i+1, num_MM))
    clean_MM = MM_to_words( test["Visible Text"][i] )
    clean_test_MM.append( clean_MM )
# Out:
# Cleaning and parsing the test set MMs...
#
# CMS MM 100 of 54559
#
# CMS MM 200 of 54559
#
# CMS MM 300 of 54559
#
# CMS MM 400 of 54559
#
# CMS MM 500 of 54559
#
# CMS MM 600 of 54559
#
# CMS MM 700 of 54559
#
# CMS MM 800 of 54559
#
# CMS MM 900 of 54559
#
# CMS MM 1000 of 54559
#
# CMS MM 1100 of 54559
#
# CMS MM 1200 of 54559
#
# CMS MM 1300 of 54559
#
# CMS MM 1400 of 54559
#
# CMS MM 1500 of 54559
#
# CMS MM 1600 of 54559
#
# CMS MM 1700 of 54559
#
# CMS MM 1800 of 54559
#
# CMS MM 1900 of 54559
#
# CMS MM 2000 of 54559
#
# CMS MM 2100 of 54559
#
# CMS MM 2200 of 54559
#
# CMS MM 2300 of 54559
#
# CMS MM 2400 of 54559
#
# CMS MM 2500 of 54559
#
# CMS MM 2600 of 54559
#
# CMS MM 2700 of 54559
#
# CMS MM 2800 of 54559
#
# CMS MM 2900 of 54559
#
# CMS MM 3000 of 54559
#
# CMS MM 3100 of 54559
#
# CMS MM 3200 of 54559
#
# CMS MM 3300 of 54559
#
# CMS MM 3400 of 54559
#
# CMS MM 3500 of 54559
#
# CMS MM 3600 of 54559
#
# CMS MM 3700 of 54559
#
# CMS MM 3800 of 54559
#
# CMS MM 3900 of 54559
#
# CMS MM 4000 of 54559
#
# CMS MM 4100 of 54559
#
# CMS MM 4200 of 54559
#
# CMS MM 4300 of 54559
#
# CMS MM 4400 of 54559
#
# CMS MM 4500 of 54559
#
# CMS MM 4600 of 54559
#
# CMS MM 4700 of 54559
#
# CMS MM 4800 of 54559
#
# CMS MM 4900 of 54559
#
# CMS MM 5000 of 54559
#
# CMS MM 5100 of 54559
#
# CMS MM 5200 of 54559
#
# CMS MM 5300 of 54559
#
# CMS MM 5400 of 54559
#
# CMS MM 5500 of 54559
#
# CMS MM 5600 of 54559
#
# CMS MM 5700 of 54559
#
# CMS MM 5800 of 54559
#
# CMS MM 5900 of 54559
#
# CMS MM 6000 of 54559
#
# CMS MM 6100 of 54559
#
# CMS MM 6200 of 54559
#
# CMS MM 6300 of 54559
#
# CMS MM 6400 of 54559
#
# CMS MM 6500 of 54559
#
# CMS MM 6600 of 54559
#
# CMS MM 6700 of 54559
#
# CMS MM 6800 of 54559
#
# CMS MM 6900 of 54559
#
# CMS MM 7000 of 54559
#
# CMS MM 7100 of 54559
#
# CMS MM 7200 of 54559
#
# CMS MM 7300 of 54559
#
# CMS MM 7400 of 54559
#
# CMS MM 7500 of 54559
#
# CMS MM 7600 of 54559
#
# CMS MM 7700 of 54559
#
# CMS MM 7800 of 54559
#
# CMS MM 7900 of 54559
#
# CMS MM 8000 of 54559
#
# CMS MM 8100 of 54559
#
# CMS MM 8200 of 54559
#
# CMS MM 8300 of 54559
#
# CMS MM 8400 of 54559
#
# CMS MM 8500 of 54559
#
# CMS MM 8600 of 54559
#
# CMS MM 8700 of 54559
#
# CMS MM 8800 of 54559
#
# CMS MM 8900 of 54559
#
# CMS MM 9000 of 54559
#
# CMS MM 9100 of 54559
#
# CMS MM 9200 of 54559
#
# CMS MM 9300 of 54559
#
# CMS MM 9400 of 54559
#
# CMS MM 9500 of 54559
#
# CMS MM 9600 of 54559
#
# CMS MM 9700 of 54559
#
# CMS MM 9800 of 54559
#
# CMS MM 9900 of 54559
#
# CMS MM 10000 of 54559
#
# CMS MM 10100 of 54559
#
# CMS MM 10200 of 54559
#
# CMS MM 10300 of 54559
#
# CMS MM 10400 of 54559
#
# CMS MM 10500 of 54559
#
# CMS MM 10600 of 54559
#
# CMS MM 10700 of 54559
#
# CMS MM 10800 of 54559
#
# CMS MM 10900 of 54559
#
# CMS MM 11000 of 54559
#
# CMS MM 11100 of 54559
#
# CMS MM 11200 of 54559
#
# CMS MM 11300 of 54559
#
# CMS MM 11400 of 54559
#
# CMS MM 11500 of 54559
#
# CMS MM 11600 of 54559
#
# CMS MM 11700 of 54559
#
# CMS MM 11800 of 54559
#
# CMS MM 11900 of 54559
#
# CMS MM 12000 of 54559
#
# CMS MM 12100 of 54559
#
# CMS MM 12200 of 54559
#
# CMS MM 12300 of 54559
#
# CMS MM 12400 of 54559
#
# CMS MM 12500 of 54559
#
# CMS MM 12600 of 54559
#
# CMS MM 12700 of 54559
#
# CMS MM 12800 of 54559
#
# CMS MM 12900 of 54559
#
# CMS MM 13000 of 54559
#
# CMS MM 13100 of 54559
#
# CMS MM 13200 of 54559
#
# CMS MM 13300 of 54559
#
# CMS MM 13400 of 54559
#
# CMS MM 13500 of 54559
#
# CMS MM 13600 of 54559
#
# CMS MM 13700 of 54559
#
# CMS MM 13800 of 54559
#
# CMS MM 13900 of 54559
#
# CMS MM 14000 of 54559
#
# CMS MM 14100 of 54559
#
# CMS MM 14200 of 54559
#
# CMS MM 14300 of 54559
#
# CMS MM 14400 of 54559
#
# CMS MM 14500 of 54559
#
# CMS MM 14600 of 54559
#
# CMS MM 14700 of 54559
#
# CMS MM 14800 of 54559
#
# CMS MM 14900 of 54559
#
# CMS MM 15000 of 54559
#
# CMS MM 15100 of 54559
#
# CMS MM 15200 of 54559
#
# CMS MM 15300 of 54559
#
# CMS MM 15400 of 54559
#
# CMS MM 15500 of 54559
#
# CMS MM 15600 of 54559
#
# CMS MM 15700 of 54559
#
# CMS MM 15800 of 54559
#
# CMS MM 15900 of 54559
#
# CMS MM 16000 of 54559
#
# CMS MM 16100 of 54559
#
# CMS MM 16200 of 54559
#
# CMS MM 16300 of 54559
#
# CMS MM 16400 of 54559
#
# CMS MM 16500 of 54559
#
# CMS MM 16600 of 54559
#
# CMS MM 16700 of 54559
#
# CMS MM 16800 of 54559
#
# CMS MM 16900 of 54559
#
# CMS MM 17000 of 54559
#
# CMS MM 17100 of 54559
#
# CMS MM 17200 of 54559
#
# CMS MM 17300 of 54559
#
# CMS MM 17400 of 54559
#
# CMS MM 17500 of 54559
#
# CMS MM 17600 of 54559
#
# CMS MM 17700 of 54559
#
# CMS MM 17800 of 54559
#
# CMS MM 17900 of 54559
#
# CMS MM 18000 of 54559
#
# CMS MM 18100 of 54559
#
# CMS MM 18200 of 54559
#
# CMS MM 18300 of 54559
#
# CMS MM 18400 of 54559
#
# CMS MM 18500 of 54559
#
# CMS MM 18600 of 54559
#
# CMS MM 18700 of 54559
#
# CMS MM 18800 of 54559
#
# CMS MM 18900 of 54559
#
# CMS MM 19000 of 54559
#
# CMS MM 19100 of 54559
#
# CMS MM 19200 of 54559
#
# CMS MM 19300 of 54559
#
# CMS MM 19400 of 54559
#
# CMS MM 19500 of 54559
#
# CMS MM 19600 of 54559
#
# CMS MM 19700 of 54559
#
# CMS MM 19800 of 54559
#
# CMS MM 19900 of 54559
#
# CMS MM 20000 of 54559
#
# CMS MM 20100 of 54559
#
# CMS MM 20200 of 54559
#
# CMS MM 20300 of 54559
#
# CMS MM 20400 of 54559
#
# CMS MM 20500 of 54559
#
# CMS MM 20600 of 54559
#
# CMS MM 20700 of 54559
#
# CMS MM 20800 of 54559
#
# CMS MM 20900 of 54559
#
# CMS MM 21000 of 54559
#
# CMS MM 21100 of 54559
#
# CMS MM 21200 of 54559
#
# CMS MM 21300 of 54559
#
# CMS MM 21400 of 54559
#
# CMS MM 21500 of 54559
#
# CMS MM 21600 of 54559
#
# CMS MM 21700 of 54559
#
# CMS MM 21800 of 54559
#
# CMS MM 21900 of 54559
#
# CMS MM 22000 of 54559
#
# CMS MM 22100 of 54559
#
# CMS MM 22200 of 54559
#
# CMS MM 22300 of 54559
#
# CMS MM 22400 of 54559
#
# CMS MM 22500 of 54559
#
# CMS MM 22600 of 54559
#
# CMS MM 22700 of 54559
#
# CMS MM 22800 of 54559
#
# CMS MM 22900 of 54559
#
# CMS MM 23000 of 54559
#
# CMS MM 23100 of 54559
#
# CMS MM 23200 of 54559
#
# CMS MM 23300 of 54559
#
# CMS MM 23400 of 54559
#
# CMS MM 23500 of 54559
#
# CMS MM 23600 of 54559
#
# CMS MM 23700 of 54559
#
# CMS MM 23800 of 54559
#
# CMS MM 23900 of 54559
#
# CMS MM 24000 of 54559
#
# CMS MM 24100 of 54559
#
# CMS MM 24200 of 54559
#
# CMS MM 24300 of 54559
#
# CMS MM 24400 of 54559
#
# CMS MM 24500 of 54559
#
# CMS MM 24600 of 54559
#
# CMS MM 24700 of 54559
#
# CMS MM 24800 of 54559
#
# CMS MM 24900 of 54559
#
# CMS MM 25000 of 54559
#
# CMS MM 25100 of 54559
#
# CMS MM 25200 of 54559
#
# CMS MM 25300 of 54559
#
# CMS MM 25400 of 54559
#
# CMS MM 25500 of 54559
#
# CMS MM 25600 of 54559
#
# CMS MM 25700 of 54559
#
# CMS MM 25800 of 54559
#
# CMS MM 25900 of 54559
#
# CMS MM 26000 of 54559
#
# CMS MM 26100 of 54559
#
# CMS MM 26200 of 54559
#
# CMS MM 26300 of 54559
#
# CMS MM 26400 of 54559
#
# CMS MM 26500 of 54559
#
# CMS MM 26600 of 54559
#
# CMS MM 26700 of 54559
#
# CMS MM 26800 of 54559
#
# CMS MM 26900 of 54559
#
# CMS MM 27000 of 54559
#
# CMS MM 27100 of 54559
#
# CMS MM 27200 of 54559
#
# CMS MM 27300 of 54559
#
# CMS MM 27400 of 54559
#
# CMS MM 27500 of 54559
#
# CMS MM 27600 of 54559
#
# CMS MM 27700 of 54559
#
# CMS MM 27800 of 54559
#
# CMS MM 27900 of 54559
#
# CMS MM 28000 of 54559
#
# CMS MM 28100 of 54559
#
# CMS MM 28200 of 54559
#
# CMS MM 28300 of 54559
#
# CMS MM 28400 of 54559
#
# CMS MM 28500 of 54559
#
# CMS MM 28600 of 54559
#
# CMS MM 28700 of 54559
#
# CMS MM 28800 of 54559
#
# CMS MM 28900 of 54559
#
# CMS MM 29000 of 54559
#
# CMS MM 29100 of 54559
#
# CMS MM 29200 of 54559
#
# CMS MM 29300 of 54559
#
# CMS MM 29400 of 54559
#
# CMS MM 29500 of 54559
#
# CMS MM 29600 of 54559
#
# CMS MM 29700 of 54559
#
# CMS MM 29800 of 54559
#
# CMS MM 29900 of 54559
#
# CMS MM 30000 of 54559
#
# CMS MM 30100 of 54559
#
# CMS MM 30200 of 54559
#
# CMS MM 30300 of 54559
#
# CMS MM 30400 of 54559
#
# CMS MM 30500 of 54559
#
# CMS MM 30600 of 54559
#
# CMS MM 30700 of 54559
#
# CMS MM 30800 of 54559
#
# CMS MM 30900 of 54559
#
# CMS MM 31000 of 54559
#
# CMS MM 31100 of 54559
#
# CMS MM 31200 of 54559
#
# CMS MM 31300 of 54559
#
# CMS MM 31400 of 54559
#
# CMS MM 31500 of 54559
#
# CMS MM 31600 of 54559
#
# CMS MM 31700 of 54559
#
# CMS MM 31800 of 54559
#
# CMS MM 31900 of 54559
#
# CMS MM 32000 of 54559
#
# CMS MM 32100 of 54559
#
# CMS MM 32200 of 54559
#
# CMS MM 32300 of 54559
#
# CMS MM 32400 of 54559
#
# CMS MM 32500 of 54559
#
# CMS MM 32600 of 54559
#
# CMS MM 32700 of 54559
#
# CMS MM 32800 of 54559
#
# CMS MM 32900 of 54559
#
# CMS MM 33000 of 54559
#
# CMS MM 33100 of 54559
#
# CMS MM 33200 of 54559
#
# CMS MM 33300 of 54559
#
# CMS MM 33400 of 54559
#
# CMS MM 33500 of 54559
#
# CMS MM 33600 of 54559
#
# CMS MM 33700 of 54559
#
# CMS MM 33800 of 54559
#
# CMS MM 33900 of 54559
#
# CMS MM 34000 of 54559
#
# CMS MM 34100 of 54559
#
# CMS MM 34200 of 54559
#
# CMS MM 34300 of 54559
#
# CMS MM 34400 of 54559
#
# CMS MM 34500 of 54559
#
# CMS MM 34600 of 54559
#
# CMS MM 34700 of 54559
#
# CMS MM 34800 of 54559
#
# CMS MM 34900 of 54559
#
# CMS MM 35000 of 54559
#
# CMS MM 35100 of 54559
#
# CMS MM 35200 of 54559
#
# CMS MM 35300 of 54559
#
# CMS MM 35400 of 54559
#
# CMS MM 35500 of 54559
#
# CMS MM 35600 of 54559
#
# CMS MM 35700 of 54559
#
# CMS MM 35800 of 54559
#
# CMS MM 35900 of 54559
#
# CMS MM 36000 of 54559
#
# CMS MM 36100 of 54559
#
# CMS MM 36200 of 54559
#
# CMS MM 36300 of 54559
#
# CMS MM 36400 of 54559
#
# CMS MM 36500 of 54559
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/1229'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/doctor'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/electrodiagnostic'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/job'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/orthopedic-specialists-of-louisiana'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/pain-care-consultants'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/robotics-and-orthopedic-surgery-a-good-pair'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://specialistshealthsystem.com/specialists-hospital'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/10-years-in-a-row-ps-achieves-guardian-of-excellence-award-again'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/2016-community-health-needs-assessment'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/2253-2'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/about'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/amenities'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/a-mother-inspires-her-son-to-pursue-his-passion'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/awards'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/cardiac-pv-lab'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/category'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/common-faqs-about-makoplasty'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/contact'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/dietary-information'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/dietary-instructions'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/directions'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/directory'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/dr-lily-embrace-everybody'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/financial'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/heart'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/imaging'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/location'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/louisiana-students-name-ps-surgical-hospital-robot'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/mako'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/medical-staff'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/meet-dr-rushton-jones-everyone-matters-2'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/other-procedures'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/our-hospitals-heart-grows-ps-welcomes-cardiologist-dr-rittelmeyer'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/outstanding-patient-satisfaction-scores-lead-award-ps-surgical-hospital'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/patient-portal'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/pediatric-surgery'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# CMS MM 36600 of 54559
#
# CMS MM 36700 of 54559
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/pre-op-and-post-op'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/prep'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-careers'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-louisianas-only-hospital-to-receive-awards'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-named-best-of-the-delta-twice-in-2015'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-named-one-of-americas-best-hospital-for-orthopedics'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-nationally-recognized-for-joint-replacement-excellence'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgeon-recalls-his-service-in-vietnam-war'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-2012-community-health-needs-assessment'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-among-the-nations-top-two-percent'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-deemed-gyn-center-of-excellence'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-earns-capstone-award'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-is-regions-first-to-offer-hip-knee-robotic-arm-technology'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-named-in-top-45'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-offers-regions-only-home-device-to-monitor-heart-failure'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-ranked-in-the-nations-top-5-percent'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-receives-champions-quality-care-award'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-receives-five-star-ratings-two-specialties-2'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-receives-guardian-of-excellence-award'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-receives-national-patient-safety-award'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-recognized-for-quality-cost-effective-bariatric-surgery'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ps-surgical-hospital-the-regions-first-bcbs-distinction-center-for-total-joint-surgeries'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/quality-patient-satisfaction'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/shoulder'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/students-participate-in-simulated-surgery-at-ps'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/surgery'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/tel:3183884040'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/tjp'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/total-joint-program'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/ulm-presidents-academy-students-are-heart-electricians-at-ps-surgical-hospital'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://pssurgery.com/what-is-osteoarthritis'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://memorialhermannkingwood.com/'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://memorialhermannkingwood.com/~'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://memorialhermannkingwood.com/about%20us'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'http://memorialhermannkingwood.com/about%20your%20surgery'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# ...
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/family-health-centers'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/financial-assistance'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/find-a-provider'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/foundation'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/healthcenters'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/home'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/hospital'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/hospital-services'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/intranet'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/myh__trashed'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/news'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/newsevents'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/news-stories'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/out-of-network-consumer-protection-law'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/patient-stories'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/patientvisitor-info'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/preparing-for-surgery'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/privacy-practices'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/receive-our-newsletter'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/services'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/share-in-the-care-gala'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\bs4\__init__.py:207: UserWarning: "b'https://www.communitymemorial.org/share-your-story'" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# CMS MM 37400 of 54559
#
# CMS MM 37500 of 54559
#
# CMS MM 37600 of 54559
#
# CMS MM 37700 of 54559
#
# CMS MM 37800 of 54559
#
# CMS MM 37900 of 54559
#
# CMS MM 38000 of 54559
#
# CMS MM 38100 of 54559
#
# CMS MM 38200 of 54559
#
# CMS MM 38300 of 54559
#
# CMS MM 38400 of 54559
#
# CMS MM 38500 of 54559
#
# CMS MM 38600 of 54559
#
# CMS MM 38700 of 54559
#
# CMS MM 38800 of 54559
#
# CMS MM 38900 of 54559
#
# CMS MM 39000 of 54559
#
# CMS MM 39100 of 54559
#
# CMS MM 39200 of 54559
#
# CMS MM 39300 of 54559
#
# CMS MM 39400 of 54559
#
# CMS MM 39500 of 54559
#
# CMS MM 39600 of 54559
#
# CMS MM 39700 of 54559
#
# CMS MM 39800 of 54559
#
# CMS MM 39900 of 54559
#
# CMS MM 40000 of 54559
#
# CMS MM 40100 of 54559
#
# CMS MM 40200 of 54559
#
# CMS MM 40300 of 54559
#
# CMS MM 40400 of 54559
#
# CMS MM 40500 of 54559
#
# CMS MM 40600 of 54559
#
# CMS MM 40700 of 54559
#
# CMS MM 40800 of 54559
#
# CMS MM 40900 of 54559
#
# CMS MM 41000 of 54559
#
# CMS MM 41100 of 54559
#
# CMS MM 41200 of 54559
#
# CMS MM 41300 of 54559
#
# CMS MM 41400 of 54559
#
# CMS MM 41500 of 54559
#
# CMS MM 41600 of 54559
#
# CMS MM 41700 of 54559
#
# CMS MM 41800 of 54559
#
# CMS MM 41900 of 54559
#
# CMS MM 42000 of 54559
#
# CMS MM 42100 of 54559
#
# CMS MM 42200 of 54559
#
# CMS MM 42300 of 54559
#
# CMS MM 42400 of 54559
#
# CMS MM 42500 of 54559
#
# CMS MM 42600 of 54559
#
# CMS MM 42700 of 54559
#
# CMS MM 42800 of 54559
#
# CMS MM 42900 of 54559
#
# CMS MM 43000 of 54559
#
# CMS MM 43100 of 54559
#
# CMS MM 43200 of 54559
#
# CMS MM 43300 of 54559
#
# CMS MM 43400 of 54559
#
# CMS MM 43500 of 54559
#
# CMS MM 43600 of 54559
#
# CMS MM 43700 of 54559
#
# CMS MM 43800 of 54559
#
# CMS MM 43900 of 54559
#
# CMS MM 44000 of 54559
#
# CMS MM 44100 of 54559
#
# CMS MM 44200 of 54559
#
# CMS MM 44300 of 54559
#
# CMS MM 44400 of 54559
#
# CMS MM 44500 of 54559
#
# CMS MM 44600 of 54559
#
# CMS MM 44700 of 54559
#
# CMS MM 44800 of 54559
#
# CMS MM 44900 of 54559
#
# CMS MM 45000 of 54559
#
# CMS MM 45100 of 54559
#
# CMS MM 45200 of 54559
#
# CMS MM 45300 of 54559
#
# CMS MM 45400 of 54559
#
# CMS MM 45500 of 54559
#
# CMS MM 45600 of 54559
#
# CMS MM 45700 of 54559
#
# CMS MM 45800 of 54559
#
# CMS MM 45900 of 54559
#
# CMS MM 46000 of 54559
#
# CMS MM 46100 of 54559
#
# CMS MM 46200 of 54559
#
# CMS MM 46300 of 54559
#
# CMS MM 46400 of 54559
#
# CMS MM 46500 of 54559
#
# CMS MM 46600 of 54559
#
# CMS MM 46700 of 54559
#
# CMS MM 46800 of 54559
#
# CMS MM 46900 of 54559
#
# CMS MM 47000 of 54559
#
# CMS MM 47100 of 54559
#
# CMS MM 47200 of 54559
#
# CMS MM 47300 of 54559
#
# CMS MM 47400 of 54559
#
# CMS MM 47500 of 54559
#
# CMS MM 47600 of 54559
#
# CMS MM 47700 of 54559
#
# CMS MM 47800 of 54559
#
# CMS MM 47900 of 54559
#
# CMS MM 48000 of 54559
#
# CMS MM 48100 of 54559
#
# CMS MM 48200 of 54559
#
# CMS MM 48300 of 54559
#
# CMS MM 48400 of 54559
#
# CMS MM 48500 of 54559
#
# CMS MM 48600 of 54559
#
# CMS MM 48700 of 54559
#
# CMS MM 48800 of 54559
#
# CMS MM 48900 of 54559
#
# CMS MM 49000 of 54559
#
# CMS MM 49100 of 54559
#
# CMS MM 49200 of 54559
#
# CMS MM 49300 of 54559
#
# CMS MM 49400 of 54559
#
# CMS MM 49500 of 54559
#
# CMS MM 49600 of 54559
#
# CMS MM 49700 of 54559
#
# CMS MM 49800 of 54559
#
# CMS MM 49900 of 54559
#
# CMS MM 50000 of 54559
#
# CMS MM 50100 of 54559
#
# CMS MM 50200 of 54559
#
# CMS MM 50300 of 54559
#
# CMS MM 50400 of 54559
#
# CMS MM 50500 of 54559
#
# CMS MM 50600 of 54559
#
# CMS MM 50700 of 54559
#
# CMS MM 50800 of 54559
#
# CMS MM 50900 of 54559
#
# CMS MM 51000 of 54559
#
# CMS MM 51100 of 54559
#
# CMS MM 51200 of 54559
#
# CMS MM 51300 of 54559
#
# CMS MM 51400 of 54559
#
# CMS MM 51500 of 54559
#
# CMS MM 51600 of 54559
#
# CMS MM 51700 of 54559
#
# CMS MM 51800 of 54559
#
# CMS MM 51900 of 54559
#
# CMS MM 52000 of 54559
#
# CMS MM 52100 of 54559
#
# CMS MM 52200 of 54559
#
# CMS MM 52300 of 54559
#
# CMS MM 52400 of 54559
#
# CMS MM 52500 of 54559
#
# CMS MM 52600 of 54559
#
# CMS MM 52700 of 54559
#
# CMS MM 52800 of 54559
#
# CMS MM 52900 of 54559
#
# CMS MM 53000 of 54559
#
# CMS MM 53100 of 54559
#
# CMS MM 53200 of 54559
#
# CMS MM 53300 of 54559
#
# CMS MM 53400 of 54559
#
# CMS MM 53500 of 54559
#
# CMS MM 53600 of 54559
#
# CMS MM 53700 of 54559
#
# CMS MM 53800 of 54559
#
# CMS MM 53900 of 54559
#
# CMS MM 54000 of 54559
#
# CMS MM 54100 of 54559
#
# CMS MM 54200 of 54559
#
# CMS MM 54300 of 54559
#
# CMS MM 54400 of 54559
#
# CMS MM 54500 of 54559

# %%
# Get a bag of words for the test set, and convert to a numpy array
vtest_data_features = vectorizer.transform(clean_test_MM)
test_data_features = vtest_data_features.toarray()

# %%
###OPTIONAL###
# If using TF-IDF, turn the test dataset vectors into TF-IDF vectors

test_data_features = TFvectorizer.transform(clean_test_MM)
testpredictors=test_data_features.toarray()

# %%
# Use the linear regression model to make CMS MM predictions
result = Lmodel.predict(test_data_features)
#result   #enable this to see what the predicted scores look like

# %%
###OPTIONAL###
# Copy the results to a pandas dataframe with an "PrimaryKey" column and
# a "MMExist" column
output = pd.DataFrame( data={"id":test["id"], "mm_predict":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "results_train-POPtest_LRM.csv", index=False, quoting=3 )

# %%
# An accuracy metric showing how well the linear model predicts on the test dataset
from sklearn.metrics import roc_auc_score
y_true = np.array(test['page_MM'])
y_scores = result
roc_auc_score(y_true, y_scores)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1875             try:
# -> 1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4027)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3891)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12408)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12359)()
#
# KeyError: 'page_MM'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-1cd0d7790921> in <module>()
#       1 # An accuracy metric showing how well the linear model predicts on the test dataset
#       2 from sklearn.metrics import roc_auc_score
# ----> 3 y_true = np.array(test['page_MM'])
#       4 y_scores = result
#       5 roc_auc_score(y_true, y_scores)
#
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\lickfett-john\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4027)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3891)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12408)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12359)()
#
# KeyError: 'page_MM'

# %% [markdown]
# ### Plot the ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
import random

# %%
expectedtest = np.array(test["page_MM"])
predicted_test = result

# %%
#false_positive_rate, true_positive_rate, thresholds = roc_curve(actual, result)
false_positive_rate, true_positive_rate, thresholds = roc_curve(expectedtest, predicted_test)
roc_auc = auc(false_positive_rate, true_positive_rate)

# %%
# There is a tradeoff betwen the TPR and FPR as we move the threshold of the classifier.
# When the test is more accurate the roc curve is closer to the left top borders
# A useless classifier is one that has its ROC curve exactly aligned with the diagonal.


plt.title('Receiver Operating Characteristic (ROC)')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# Concerning the AUC, a simple rule of thumb to evaluate a classifier based on this summary value is the following:

# .90-1 = very good (A)
# .80-.90 = good (B)
# .70-.80 = not so good (C)
# .60-.70 = poor (D)
# .50-.60 = fail (F)
