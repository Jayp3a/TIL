# %% [markdown]
# # Bag of Words => Random Forest Model Training
# Borrowed from https://www.kaggle.com/c/word2vec-nlp-tutorial/details/part-1-for-beginners-bag-of-words
# You will need to download two datasets, named "labeledTrainData.tsv" and "testData.tsv".  They can be found at: https://www.kaggle.com/c/word2vec-nlp-tutorial/data
# An accompanying code file can be found at https://github.com/wendykan/DeepLearningMovies/blob/master/BagOfWords.py

# %% [markdown]
# ### Read the data file, and take a minute to examine the dataset

# %%
# Import the pandas package, then use the "read_csv" function to read
# the labeled training data
import os
import pandas as pd
import numpy as np

# %%
# Set the working directory to the folder where your data is stored
os.chdir("C:\\Users\lickfett-john\Documents\Python Scripts")
# See what files are in the folder.
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'all_training.csv',
#  'all_training.xlsx',
#  'archive',
#  'from the scrapy projects folder',
#  'test results files',
#  'test.xlsx',
#  'TIL_Webscrape_FINAL.ipynb',
#  'train.xlsx',
#  'url_extract_crawler',
#  'validate.xlsx']

# %%
# Read the training data
train = pd.read_excel("train.xlsx", header=0, \
                    delimiter="\t", quoting=3)

#   "header=0" indicates that the first line of the file contains column names, 
#   "delimiter=\t" indicates that the fields are separated by tabs,
#   quoting=3 tells Python to ignore doubled quotes, otherwise you may encounter errors trying to read the file.

# %%
## This is a step you can use if you don't have your training data already broken apart into a training and test dataset.

#from sklearn.cross_validation import train_test_split
#train, test = train_test_split( data, train_size = 0.8, random_state = 44 )

# %%
## This is a step you can use if you don't have your training data already broken apart into a training and test dataset.

#all_i = np.arange( len( data ))
#train_i, test_i = train_test_split( all_i, train_size = 0.8, random_state = 44 )

#train = data.ix[train_i]
#test = data.ix[test_i]

# %%
# check the size of the data (rows, columns)
train.shape
# output should be (# rows, # columns)
# Out:
# (127, 6)

# %%
# check the column labels
train.columns.values
# output should be array(['PrimaryKey', 'Provider Type', 'SampleID', 'P_Name', 'P_City',
#       'P_State', 'P_Street', 'P_Zip', 'Stars', 'URL', 'CMS_Text',
#       'Contains CMS MM?'], dtype=object)
# Out:
# array(['id', 'Provider Type', 'root url', 'scraped url', 'Visible Text',
#        'page_MM'], dtype=object)

# %%
# Look at the first five values of the CMS MM data.
# MMs are coded as 1 or 0, for MM found or MM not found.
train["page_MM"][:5]
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: page_MM, dtype: int64

# %%
# take a look at the text in the first CMS MM
train["Visible Text"][0]
# Out:
# 'Skip to main content Home Careers About Us Every Day Giving Excellence Search Menu For Patients About Your Surgery Your Rights and Responsibilities Your Privacy Financial Information Information in Espanol Nondiscrimination Notice Staff & Physicians About Us Employment Opportunities Contact Us Print Email Home \r\r\n$name Address and Directions \r\r\n        600 Sioux Point Road  \r\r\n        Dakota Dunes, South Dakota, 57049\r\r\n         Phone: 605-232-3332 Fax:  Hours of Operation: \r\r\n        Monday-Friday \r\r\n        6:00am-5:00pm\r\r\n     Driving Directions Header Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Fusce nulla ligula, sollicitudin eu, adipiscing tincidunt, bibendum et, augue. Phasellus eget lacus sed lacus sagittis facilisis. Morbi id est sed mi facilisis venenatis. Nulla ut ante sit amet risus tempor vestibulum. Donec laoreet. Mauris convallis adipiscing arcu. Learn More About Your Surgery Your Rights and Responsibilities Your Privacy Financial Information Information in Espanol Nondiscrimination Notice We are an affiliate of United Surgical Partners International, partnered with local physicians, and accredited by Accreditation Association for Hospitals/Health Systems. For a list of owners please contact us. We are fully licensed by the state of South Dakota and are Medicare certified. FACEBOOK LINK TWITTER LINK PINTEREST LINK © 2016 Dunes Surgical Hospital FAQ Terms & Conditions Privacy Policy Contact Us Sitemap \r\r\n                        Web site design and development by  Americaneagle.com'

# %%
# There are HTML tags such as "<br/>", abbreviations, punctuation - all common issues when processing text from online. 
# First, we'll remove the HTML tags. For this purpose, we'll use the Beautiful Soup library.


# Import BeautifulSoup into your workspace
import bs4
from bs4 import BeautifulSoup             

# Initialize the BeautifulSoup object on a single CMS MM     
example1 = BeautifulSoup(train["Visible Text"][0],"lxml")

# Print the raw CMS MM and then the output of get_text(), for 
# comparison
# train["Visible Text"][0]

# %%
# compare the raw CMS MM above with the get_text ouput below
# example1.get_text()

# %% [markdown]
# ### Clean the Text
#
# When considering how to clean the text, we should think about the data problem we are trying to solve.
# For many problems, it makes sense to remove punctuation.
# In this tutorial, for simplicity, we remove the punctuation altogether, but it is something you can play with on your own.
# Similarly, in this tutorial we will remove numbers, but there are other ways of dealing with them that make just as much sense.
# For example, we could treat them as words, or replace them all with a placeholder string such as "NUM".
# To remove punctuation and numbers, we will use a package for dealing with regular expressions, called re.
# The package comes built-in with Python; no need to install anything.
# For a detailed description of how regular expressions work, see the package documentation. Now, try the following:

# %%
import re
# Use regular expressions to do a find-and-replace
letters_only = re.sub("[^a-zA-Z4-5&-]",           # The pattern to search for
                      " ",                   # The pattern to replace it with
                      example1.get_text() )  # The text to search

# print the output of letters_only
# letters_only

# A full overview of regular expressions is beyond the scope of this tutorial, 
# but for now it is sufficient to know that [] indicates group membership and ^ means "not". 
# In other words, the re.sub() statement above says,
# "Find anything that is NOT a lowercase letter (a-z) or an upper case letter (A-Z), and replace it with a space."

# %%
# We'll also convert our CMS MMs to lower case and split them into individual words.
# This is called "tokenization" in Natural Language Processing (NLP) lingo.

lower_case = letters_only.lower()        # Convert to lower case
#words = lower_case.split()               # Split into words
letters_only
# Out:
# 'Skip to main content Home Careers About Us Every Day Giving Excellence Search Menu For Patients About Your Surgery Your Rights and Responsibilities Your Privacy Financial Information Information in Espanol Nondiscrimination Notice Staff & Physicians About Us Employment Opportunities Contact Us Print Email Home     name Address and Directions                Sioux Point Road             Dakota Dunes  South Dakota  5  4             Phone    5-   -     Fax   Hours of Operation             Monday-Friday                am-5   pm        Driving Directions Header Lorem ipsum dolor sit amet  consectetuer adipiscing elit  Fusce nulla ligula  sollicitudin eu  adipiscing tincidunt  bibendum et  augue  Phasellus eget lacus sed lacus sagittis facilisis  Morbi id est sed mi facilisis venenatis  Nulla ut ante sit amet risus tempor vestibulum  Donec laoreet  Mauris convallis adipiscing arcu  Learn More About Your Surgery Your Rights and Responsibilities Your Privacy Financial Information Information in Espanol Nondiscrimination Notice We are an affiliate of United Surgical Partners International  partnered with local physicians  and accredited by Accreditation Association for Hospitals Health Systems  For a list of owners please contact us  We are fully licensed by the state of South Dakota and are Medicare certified  FACEBOOK LINK TWITTER LINK PINTEREST LINK        Dunes Surgical Hospital FAQ Terms & Conditions Privacy Policy Contact Us Sitemap                            Web site design and development by  Americaneagle com'

# %%
# Finally, we need to decide how to deal with frequently occurring words that don't carry much meaning.
# Such words are called "stop words"; in English they include words such as "a", "and", "is", and "the".
# Conveniently, there are Python packages that come with stop word lists built in. 
# Let's import a stop word list from the Python Natural Language Toolkit (NLTK). 
# You'll need to install the library if you don't already have it on your computer;
# you'll also need to install the data packages that come with it, as follows:
#nltk.download()  # Download text data sets, including stop words
import nltk

# %%
# Now we can use NLTK to get a list of stopwords

from nltk.corpus import stopwords # Import the stop word list

# Show the stop words
# stopwords.words("english")

# %%
# This will allow you to view the list of English-language stop words. To remove stop words from our CMS MM, do:

# Remove stop words from "words"
words = [w for w in words if not w in stopwords.words("english")]

# words

# This looks at each word in our "words" list, and discards anything that is found in the list of stop words.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-6086a5ed222a> in <module>()
#       2
#       3 # Remove stop words from "words"
# ----> 4 words = [w for w in words if not w in stopwords.words("english")]
#       5
#       6 # words
#
# NameError: name 'words' is not defined

# %% [markdown]
# ### Loop the cleaning process through all of the text
#
# Now we have code to clean one CMS MM - but we need to clean hundreds of training MMs!
# To make our code reusable, let's create a function that can be called many times:

# %%
def MM_to_words( raw_MM ):
    # Function to convert a raw CMS MM to a string of words
    # The input is a single string (a raw MM text), and 
    # the output is a single string (a preprocessed MM text)
    #
    # 1. Remove HTML
    MM_text = BeautifulSoup(raw_MM,"lxml").get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z4-5&-]", " ", MM_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #    a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    #meaningful_words = [w for w in words]
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    #    to make the output easier to use in our Bag of Words,
    #    then return the result. 
    return( " ".join( meaningful_words ))

# %%
# Call the function above to test it on a single MM text

clean_MM = MM_to_words( train["Visible Text"][0] )

clean_MM
# Out:
# 'skip main content home careers us every day giving excellence search menu patients surgery rights responsibilities privacy financial information information espanol nondiscrimination notice staff & physicians us employment opportunities contact us print email home name address directions sioux point road dakota dunes south dakota 5 4 phone 5- - fax hours operation monday-friday am-5 pm driving directions header lorem ipsum dolor sit amet consectetuer adipiscing elit fusce nulla ligula sollicitudin eu adipiscing tincidunt bibendum et augue phasellus eget lacus sed lacus sagittis facilisis morbi id est sed mi facilisis venenatis nulla ut ante sit amet risus tempor vestibulum donec laoreet mauris convallis adipiscing arcu learn surgery rights responsibilities privacy financial information information espanol nondiscrimination notice affiliate united surgical partners international partnered local physicians accredited accreditation association hospitals health systems list owners please contact us fully licensed state south dakota medicare certified facebook link twitter link pinterest link dunes surgical hospital faq terms & conditions privacy policy contact us sitemap web site design development americaneagle com'

# %%
# Now let's loop through and clean all of the training set at once

# Get the number of MMs based on the dataframe column size
num_MM = train["Visible Text"].size

# Initialize an empty list to hold the clean MMs
clean_train_MM = []

# Loop over each MM; create an index i that goes from 0 to the length
# of theMM list 
for i in range( 0, num_MM ):
    # Call our function for each one, and add the result to the list of
    # clean MMs
    clean_train_MM.append( MM_to_words( train["Visible Text"][i] ) )

# This next bit is optional, and it will give you status updates for every 1,000 rows.
print ("Cleaning and parsing the training set CMS MMs...\n")
clean_train_MM = []
for i in range( 0, num_MM ):
    # If the index is evenly divisible by 10, print a message
    if( (i+1)%10 == 0 ):
        print ("MM %d of %d\n" % ( i+1, num_MM ))                                                                    
    clean_train_MM.append( MM_to_words( train["Visible Text"][i] ))
# Out:
# Cleaning and parsing the training set CMS MMs...
#
# MM 10 of 127
#
# MM 20 of 127
#
# MM 30 of 127
#
# MM 40 of 127
#
# MM 50 of 127
#
# MM 60 of 127
#
# MM 70 of 127
#
# MM 80 of 127
#
# MM 90 of 127
#
# MM 100 of 127
#
# MM 110 of 127
#
# MM 120 of 127

# %%
## If you want to see the output in a csv file, follow the steps below.
# Copy the results to a pandas dataframe.
# output = pd.DataFrame( data={"id":train["id"], "Visible Text":clean_train_MM} )

# Use pandas to write the comma-separated output file
# output.to_csv( "clean_model_text.csv", index=False, quoting=3 )

# %% [markdown]
# ### Create a Bag of Words model
# The Bag of Words model learns a vocabulary from all of the documents (CMS MMs),
# then models each document by counting the number of times each word appears.
# We'll be using the feature_extraction module from scikit-learn to create bag-of-words features.
# In the CMS MM data, we have a very large number of MMs, which will give us a large vocabulary.
# To limit the size of the feature vectors, we should choose some maximum vocabulary size.
# Below, we use the 5000 most frequent words (remembering that stop words have already been removed).

# %%
print ("Creating the bag of words...\n")

import sklearn
# If you are using Anaconda, Sci-Kit Learn should already be installed. Otherwise you will have to install it.
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 10000) # This limits to the 10,000 most frequent words

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_MM)

# Numpy arrays are easy to work with, so convert the result to an \

# array
train_data_features = train_data_features.toarray()


# NOTE: CountVectorizer comes with its own options to automatically do preprocessing,
# tokenization, and stop word removal -- for each of these, instead of specifying "None",
# we could have used a built-in method or specified our own function to use.
# However, we wanted to write our own function for data cleaning in this tutorial 
# to show you how it's done step by step.
# Out:
# Creating the bag of words...

# %%
# To see what the training data array now looks like, do:
train_data_features.shape
# The output should read (# rows, # of text features)
# The # of text features is a count of each vocabulary word.
# Out:
# (127, 7384)

# %%
# Now that the Bag of Words model is trained, let's look at the vocabulary.
vocab = vectorizer.get_feature_names()

vocab
# Out:
# ['44',
#  '444',
#  '445',
#  '4455',
#  '44th',
#  '45',
#  '454',
#  '455',
#  '4th',
#  '54',
#  '544',
#  '545',
#  '55',
#  '555',
#  '5a',
#  '5th',
#  'aahrpp',
#  'aamc',
#  'abbeville',
#  'abbey',
#  'abdomen',
#  'abilities',
#  'ability',
#  'abim',
#  'abington',
#  'able',
#  'abos',
#  'abpts',
#  'abraham',
#  'absences',
#  'abundant',
#  'abuse',
#  'academic',
#  'academy',
#  'accentuates',
#  'accept',
#  'accepted',
#  'accepting',
#  'accepts',
#  'access',
#  'accessibility',
#  'accessible',
#  'accessory',
#  'acclaimed',
#  'accolades',
#  'accommodate',
#  'accommodates',
#  'accommodations',
#  'accompanied',
#  'accomplished',
#  'accomplishments',
#  'accordance',
#  'according',
#  'accordingly',
#  'account',
#  'accountability',
#  'accounting',
#  'accounts',
#  'accreditation',
#  'accreditations',
#  'accredited',
#  'accrediting',
#  'accreditor',
#  'accredits',
#  'accurate',
#  'accusantium',
#  'accustomed',
#  'ace',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'acknowledges',
#  'acls',
#  'acquainted',
#  'acquired',
#  'acquires',
#  'acres',
#  'across',
#  'acs',
#  'act',
#  'action',
#  'actions',
#  'activation',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'actual',
#  'actually',
#  'acupuncture',
#  'acute',
#  'adamawa',
#  'adams',
#  'add',
#  'addcontroltocontainer',
#  'added',
#  'addiction',
#  'addition',
#  'additional',
#  'additions',
#  'address',
#  'addressed',
#  'addresses',
#  'addressing',
#  'adds',
#  'adequate',
#  'adequately',
#  'adipiscing',
#  'adipisicing',
#  'adirondack',
#  'adjust',
#  'adjustment',
#  'adjustments',
#  'admin',
#  'administered',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'adminsr',
#  'admission',
#  'admissions',
#  'admit',
#  'admittance',
#  'admitted',
#  'admitting',
#  'adn',
#  'adolescent',
#  'adoption',
#  'adrenal',
#  'ads',
#  'adult',
#  'adulthood',
#  'adults',
#  'advance',
#  'advanced',
#  'advancements',
#  'advantage',
#  'adventure',
#  'adventures',
#  'advertisement',
#  'advertising',
#  'advice',
#  'advise',
#  'advisors',
#  'advisory',
#  'advocacy',
#  'advocate',
#  'advocates',
#  'affairs',
#  'affect',
#  'affection',
#  'affects',
#  'affiliate',
#  'affiliated',
#  'affiliates',
#  'affiliation',
#  'affiliations',
#  'affilliate',
#  'affordable',
#  'afm',
#  'afrikaans',
#  'after',
#  'aftercare',
#  'agana',
#  'agate',
#  'age',
#  'ageless',
#  'agencies',
#  'agency',
#  'agendas',
#  'agents',
#  'ages',
#  'aggressively',
#  'aging',
#  'agnes',
#  'ago',
#  'agree',
#  'agreement',
#  'aguayo',
#  'aha',
#  'ahca',
#  'ahead',
#  'ahu',
#  'aia',
#  'aid',
#  'aide',
#  'aides',
#  'aids',
#  'ailment',
#  'aim',
#  'aiming',
#  'air',
#  'airport',
#  'ais',
#  'ait',
#  'aitkin',
#  'aj',
#  'ajax',
#  'ak',
#  'akin',
#  'akron',
#  'al',
#  'alabama',
#  'alarmed',
#  'alaska',
#  'albanian',
#  'albertville',
#  'albums',
#  'albuquerque',
#  'alcohol',
#  'alene',
#  'alert',
#  'alerts',
#  'alertss',
#  'alexandria',
#  'alfred',
#  'all',
#  'alla',
#  'allen',
#  'allergies',
#  'allergy',
#  'alliance',
#  'allogeneic',
#  'allow',
#  'allowances',
#  'allowed',
#  'allowing',
#  'allows',
#  'almh',
#  'almond',
#  'almost',
#  'alone',
#  'along',
#  'alongside',
#  'alphabetically',
#  'already',
#  'also',
#  'alt',
#  'alterg',
#  'alternate',
#  'alternatives',
#  'although',
#  'altus',
#  'alumni',
#  'alvin',
#  'always',
#  'alzheimer',
#  'am',
#  'amanda',
#  'amazing',
#  'ambulance',
#  'ambulatory',
#  'amenities',
#  'amenity',
#  'ameravant',
#  'america',
#  'american',
#  'americaneagle',
#  'americans',
#  'americinn',
#  'americorps',
#  'amet',
#  'ami',
#  'amidst',
#  'among',
#  'amory',
#  'amos',
#  'amount',
#  'amp',
#  'amy',
#  'ana',
#  'anacortes',
#  'analysts',
#  'analytics',
#  'analyzed',
#  'analyzes',
#  'anamaria',
#  'anania',
#  'anatomic',
#  'anatomy',
#  'and',
#  'andalusia',
#  'anderson',
#  'andes',
#  'andover',
#  'andrew',
#  'anemia',
#  'anesthesia',
#  'anesthesiologist',
#  'anesthesiology',
#  'anesthetist',
#  'anesthetists',
#  'aneurysms',
#  'anew',
#  'angela',
#  'angeles',
#  'angell',
#  'angelo',
#  'angels',
#  'angie',
#  'angina',
#  'angles',
#  'ankle',
#  'ankles',
#  'ann',
#  'annandale',
#  'anne',
#  'anniston',
#  'anniversary',
#  'announce',
#  'announced',
#  'announcements',
#  'announcing',
#  'annual',
#  'annually',
#  'anonymous',
#  'another',
#  'anp',
#  'answer',
#  'answers',
#  'ante',
#  'anterior',
#  'anthem',
#  'anti',
#  'antiaging',
#  'antibiotics',
#  'anticipating',
#  'anticipation',
#  'anticoagulation',
#  'antifungal',
#  'antioch',
#  'antipsychotics',
#  'antiques',
#  'antonio',
#  'anxiety',
#  'anyone',
#  'anything',
#  'anytime',
#  'apartment',
#  'apartments',
#  'api',
#  'aplushhh',
#  'apologize',
#  'apopka',
#  'app',
#  'apparel',
#  'apparent',
#  'appeal',
#  'appetizer',
#  'appetizers',
#  'appetizing',
#  'apple',
#  'apples',
#  'appliances',
#  'applicable',
#  'applicants',
#  'application',
#  'applications',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appointed',
#  'appointment',
#  'appointments',
#  'appraisals',
#  'appreciation',
#  'approach',
#  'approaches',
#  'appropriate',
#  'approval',
#  'approved',
#  'approximately',
#  'apps',
#  'april',
#  'aquarium',
#  'aquatic',
#  'aquatics',
#  'ar',
#  'arabic',
#  'arbor',
#  'arboretum',
#  'architect',
#  'archive',
#  'archives',
#  'arcu',
#  'area',
#  'areas',
#  'arena',
#  'arizona',
#  'ark',
#  'arkansas',
#  'arlene',
#  'arlington',
#  'arm',
#  'armenian',
#  'armoires',
#  'armour',
#  'arms',
#  'arnold',
#  'around',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'array',
#  'arrhythmias',
#  'arrhythmics',
#  'arrival',
#  'arrive',
#  'arrives',
#  'arriving',
#  'arrowood',
#  'arrowwood',
#  'art',
#  'arteries',
#  'artery',
#  'arthritis',
#  'arthur',
#  'article',
#  'articles',
#  'artifical',
#  'artificial',
#  'arts',
#  'artwork',
#  'arugula',
#  'asap',
#  'asheville',
#  'ashevilleart',
#  'ashevilletheatre',
#  'ashland',
#  'ashley',
#  'asian',
#  'ask',
#  'asked',
#  'asking',
#  'aspect',
#  'aspects',
#  'aspen',
#  'aspx',
#  'assess',
#  'assessed',
#  'assesses',
#  'assessing',
#  'assessment',
#  'assessments',
#  'asset',
#  'assign',
#  'assigns',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'assisted',
#  'assisting',
#  'assists',
#  'associate',
#  'associated',
#  'associates',
#  'association',
#  'associations',
#  'assorted',
#  'assumed',
#  'assurance',
#  'assure',
#  'assured',
#  'aster',
#  'asthma',
#  'astounding',
#  'asusu',
#  'at',
#  'atchison',
#  'athens',
#  'atherosclerosis',
#  'athlete',
#  'athletes',
#  'athletic',
#  'atient',
#  'atlanta',
#  'atlantasky',
#  'atm',
#  'atmosphere',
#  'atms',
#  'attached',
#  'attachment',
#  'attack',
#  'attacks',
#  'attain',
#  'attained',
#  'attaining',
#  'attend',
#  'attendants',
#  'attended',
#  'attending',
#  'attention',
#  'attentive',
#  'attitude',
#  'attitudes',
#  'attractions',
#  'attributes',
#  'attuned',
#  'atwell',
#  'auction',
#  'audiology',
#  'auditor',
#  'audits',
#  'augue',
#  'august',
#  'augusta',
#  'aunt',
#  'austinown',
#  'austintown',
#  'author',
#  'authored',
#  'authority',
#  'authorization',
#  'autism',
#  'auto',
#  'autographed',
#  'autologous',
#  'automated',
#  'automotive',
#  'auxiliary',
#  'availability',
#  'available',
#  'avatar',
#  'ave',
#  'avenue',
#  'avera',
#  'average',
#  'averages',
#  'averanow',
#  'avh',
#  'avid',
#  'avocado',
#  'avoid',
#  'avon',
#  'award',
#  'awarded',
#  'awards',
#  'awared',
#  'awareness',
#  'away',
#  'awhile',
#  'ayisyen',
#  'ayobami',
#  'az',
#  'azerbaijani',
#  'ba',
#  'babies',
#  'baby',
#  'bacara',
#  'bachelor',
#  'bachelors',
#  'back',
#  'background',
#  'backstreet',
#  'backyard',
#  'bacteria',
#  'bad',
#  'bag',
#  'baggies',
#  'bahamas',
#  'bailey',
#  'baker',
#  'balance',
#  'baldwin',
#  'ball',
#  'balloon',
#  'ballots',
#  'balls',
#  'ballston',
#  'balm',
#  'baltimore',
#  'band',
#  'bank',
#  'baptist',
#  'bar',
#  'baraboo',
#  'barbara',
#  'barber',
#  'bariatric',
#  'bariatrics',
#  'barre',
#  'barrie',
#  'barry',
#  'barstock',
#  'barton',
#  'base',
#  'baseball',
#  'basecamp',
#  'based',
#  'baseline',
#  'basic',
#  'basically',
#  'basis',
#  'basket',
#  'basque',
#  'bass',
#  'bassett',
#  'bate',
#  'bath',
#  'bathing',
#  'bathrooms',
#  'baths',
#  'baton',
#  'battle',
#  'baxter',
#  'bay',
#  'baylor',
#  'bayside',
#  'bbq',
#  'bc',
#  'bcmh',
#  'beach',
#  'beal',
#  'bear',
#  'beat',
#  'beaudette',
#  'beautiful',
#  'beauty',
#  'became',
#  'beck',
#  'becker',
#  'become',
#  'becomes',
#  'bed',
#  'bedford',
#  'bedroom',
#  'bedrooms',
#  'beds',
#  'bedside',
#  'bedspreads',
#  'beef',
#  'beer',
#  'began',
#  'begin',
#  'beginning',
#  'beginnings',
#  'begins',
#  'behavioral',
#  'behaviors',
#  'behind',
#  'being',
#  'belarusian',
#  'belief',
#  'beliefs',
#  'believe',
#  'believes',
#  'belle',
#  'bellefonte',
#  'belmont',
#  'belongings',
#  'belt',
#  'beltway',
#  'benaroya',
#  'bench',
#  'benchmarking',
#  'benchmarks',
#  'beneficial',
#  'benefit',
#  'benefited',
#  'benefits',
#  'bennett',
#  'benson',
#  'bereavement',
#  'berkshire',
#  'berlin',
#  'bernardine',
#  'berry',
#  'best',
#  'bestowed',
#  'beta',
#  'bethanie',
#  'bethesda',
#  'better',
#  'betterment',
#  'beverage',
#  'beverages',
#  'beverly',
#  'beyond',
#  'beyondnow',
#  'bhc',
#  'bhsh',
#  'bibendum',
#  'bible',
#  'bids',
#  'big',
#  'bigfork',
#  'bigforkvalley',
#  'biggs',
#  'bike',
#  'biliary',
#  'bill',
#  'billing',
#  'billpay',
#  'biltmore',
#  'biodex',
#  'biographies',
#  'biography',
#  'biology',
#  'biopsy',
#  'bios',
#  'birgit',
#  'birth',
#  'birthdays',
#  'birthing',
#  'birthplace',
#  'births',
#  'bisexual',
#  'bittersweet',
#  'bizaad',
#  'bjc',
#  'bjerkness',
#  'black',
#  'blackburn',
#  'blackmon',
#  'blackwelder',
#  'bladder',
#  'blanchette',
#  'blanding',
#  'blank',
#  'blast',
#  'blessed',
#  'blind',
#  'blint',
#  'block',
#  'blocked',
#  'blog',
#  'blognvna',
#  'blogs',
#  'blood',
#  'bloodless',
#  'blue',
#  'blueridgeparkway',
#  'bluff',
#  'blvd',
#  'blytheville',
#  'bmc',
#  'bmf',
#  'bmh',
#  'bmhutah',
#  'board',
#  'boardman',
#  'boards',
#  'boasts',
#  'boat',
#  'boaters',
#  'bob',
#  'bobbers',
#  'boca',
#  'bod',
#  'body',
#  'bohemian',
#  'bohemianhotelasheville',
#  'boiled',
#  'bold',
#  'bomgar',
#  'bon',
#  'bond',
#  'bone',
#  'bonita',
#  'book',
#  'books',
#  'boone',
#  'boost',
#  'bootstrap',
#  'border',
#  'borders',
#  'boredom',
#  'borja',
#  'born',
#  'boston',
#  'botsford',
#  'bottle',
#  'bottles',
#  'bottom',
#  'bought',
#  'boulder',
#  'boulevard',
#  'bound',
#  'boushay',
#  'boutique',
#  'bowel',
#  'bowl',
#  'bowling',
#  'bowman',
#  'box',
#  'boxes',
#  'boynton',
#  'boys',
#  'bpass',
#  'bph',
#  'br',
#  'bracelet',
#  'bradenton',
#  'bradley',
#  'brain',
#  'brainerd',
#  'braintree',
#  'branch',
#  'branches',
#  'brand',
#  'brandel',
#  'brandon',
#  'brave',
#  'breadcrumb',
#  'breadcrumbs',
#  'breads',
#  'break',
#  'breakfast',
#  'breast',
#  'breastfeeding',
#  'breath',
#  'breathe',
#  'breathing',
#  'breezy',
#  'brent',
#  'brentwood',
#  'brewing',
#  'brick',
#  'bridge',
#  'bright',
#  'brighten',
#  'brightens',
#  'brighton',
#  'bring',
#  'bringing',
#  'brings',
#  'brinker',
#  'bristol',
#  'brits',
#  'broad',
#  'broader',
#  'broadway',
#  'brochure',
#  'brochures',
#  'brock',
#  'broil',
#  'bronze',
#  'brookfield',
#  'brooklyn',
#  'brooks',
#  'brooten',
#  'brought',
#  'brouse',
#  'broward',
#  'brown',
#  'browser',
#  'bruce',
#  'brumfield',
#  'brunch',
#  'brunswick',
#  'brush',
#  'brushed',
#  'brushfire',
#  'brutal',
#  'bryant',
#  'bryner',
#  'bs',
#  'bsmc',
#  'bsn',
#  'buchsbaum',
#  'bud',
#  'buddy',
#  'buffet',
#  'buffett',
#  'build',
#  'builder',
#  'building',
#  'buildings',
#  'builds',
#  'built',
#  'bulgarian',
#  'bulk',
#  'bundled',
#  'burdett',
#  'bureau',
#  'bureaucracy',
#  'burger',
#  'burlington',
#  'burn',
#  'burton',
#  'bus',
#  'business',
#  'businesses',
#  'busting',
#  'busy',
#  'button',
#  'buy',
#  'bvactive',
#  'by',
#  'bypass',
#  'byron',
#  'ca',
#  'cabarrus',
#  'cabin',
#  'cabinets',
#  'cable',
#  'caf',
#  'cafe',
#  'cafeteria',
#  'cahps',
#  'calais',
#  'calcium',
#  'calculate',
#  'calculated',
#  'calculating',
#  'calculator',
#  'calendar',
#  'calendars',
#  'calender',
#  'calhoun',
#  'caliber',
#  'calif',
#  'california',
#  'call',
#  'called',
#  'calling',
#  'calloway',
#  'calm',
#  'calming',
#  'calorie',
#  'calories',
#  'calqualitycare',
#  'came',
#  'campaign',
#  'campbell',
#  'camping',
#  'campus',
#  'canadian',
#  'canajoharie',
#  'cancel',
#  'cancelled',
#  'cancer',
#  'cancercenter',
#  'cancers',
#  'candidates',
#  'canfield',
#  'cannot',
#  'canterbury',
#  'cap',
#  'capability',
#  'capacity',
#  'capd',
#  'cape',
#  'capital',
#  'car',
#  'card',
#  'cardiac',
#  'cardio',
#  'cardiologist',
#  'cardiology',
#  'cardiomyopathy',
#  'cardiopulmonary',
#  'cardiothoracic',
#  'cardiothoracicvascular',
#  'cardiovascular',
#  'cardon',
#  'cards',
#  'care',
#  'cared',
#  'careemploymentcontact',
#  'career',
#  'careers',
#  'careful',
#  'carefully',
#  'caregiver',
#  'caregivers',
#  'caregiving',
#  'carelaboratoryclinicprovidersradiologyabout',
#  'carelink',
#  'carepartners',
#  'cares',
#  'carf',
#  'caribbean',
#  'caribou',
#  'caring',
#  'caringbridge',
#  'carlisle',
#  'carlsbad',
#  'carlton',
#  'carol',
#  'carolina',
#  'carolinas',
#  'carpenter',
#  'carpet',
#  'carried',
#  'carrier',
#  'carroll',
#  'cart',
#  'carter',
#  'carterhealthcare',
#  'carver',
#  'cary',
#  'casa',
#  ...]

# %%
# Optionally, you can also choose to print the counts of each word in the vocabulary

import numpy as np


# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print (count, tag)
# Out:
# 29 44
# 1 444
# 6 445
# 1 4455
# 1 44th
# 25 45
# 1 454
# 1 455
# 3 4th
# 29 54
# 1 544
# 3 545
# 38 55
# 2 555
# 1 5a
# 4 5th
# 2 aahrpp
# 3 aamc
# 3 abbeville
# 1 abbey
# 1 abdomen
# 1 abilities
# 4 ability
# 1 abim
# 1 abington
# 9 able
# 1 abos
# 1 abpts
# 1 abraham
# 1 absences
# 1 abundant
# 4 abuse
# 6 academic
# 2 academy
# 1 accentuates
# 7 accept
# 22 accepted
# 3 accepting
# 4 accepts
# 47 access
# 7 accessibility
# 7 accessible
# 1 accessory
# 1 acclaimed
# 5 accolades
# 2 accommodate
# 2 accommodates
# 15 accommodations
# 2 accompanied
# 1 accomplished
# 3 accomplishments
# 5 accordance
# 10 according
# 1 accordingly
# 6 account
# 4 accountability
# 1 accounting
# 1 accounts
# 57 accreditation
# 18 accreditations
# 32 accredited
# 2 accrediting
# 2 accreditor
# 4 accredits
# 3 accurate
# 1 accusantium
# 1 accustomed
# 1 ace
# 8 achieve
# 14 achieved
# 14 achievement
# 6 achievements
# 1 achieves
# 4 achieving
# 1 acknowledges
# 1 acls
# 1 acquainted
# 7 acquired
# 1 acquires
# 2 acres
# 11 across
# 2 acs
# 8 act
# 8 action
# 1 actions
# 3 activation
# 17 active
# 5 actively
# 43 activities
# 11 activity
# 1 actual
# 1 actually
# 1 acupuncture
# 30 acute
# 1 adamawa
# 6 adams
# 2 add
# 1 addcontroltocontainer
# 13 added
# 1 addiction
# 20 addition
# 17 additional
# 2 additions
# 17 address
# 2 addressed
# 2 addresses
# 1 addressing
# 2 adds
# 2 adequate
# 1 adequately
# 3 adipiscing
# 1 adipisicing
# 1 adirondack
# 1 adjust
# 1 adjustment
# 1 adjustments
# 3 admin
# 2 administered
# 15 administration
# 5 administrative
# 16 administrator
# 4 administrators
# 1 adminsr
# 12 admission
# 11 admissions
# 2 admit
# 1 admittance
# 1 admitted
# 2 admitting
# 1 adn
# 3 adolescent
# 1 adoption
# 1 adrenal
# 5 ads
# 34 adult
# 1 adulthood
# 6 adults
# 17 advance
# 30 advanced
# 2 advancements
# 6 advantage
# 2 adventure
# 3 adventures
# 1 advertisement
# 6 advertising
# 4 advice
# 1 advise
# 1 advisors
# 2 advisory
# 4 advocacy
# 3 advocate
# 1 advocates
# 3 affairs
# 1 affect
# 1 affection
# 1 affects
# 5 affiliate
# 1 affiliated
# 7 affiliates
# 4 affiliation
# 5 affiliations
# 1 affilliate
# 4 affordable
# 9 afm
# 2 afrikaans
# 2 after
# 1 aftercare
# 1 agana
# 1 agate
# 14 age
# 1 ageless
# 22 agencies
# 42 agency
# 1 agendas
# 3 agents
# 4 ages
# 1 aggressively
# 10 aging
# 1 agnes
# 1 ago
# 1 agree
# 4 agreement
# 3 aguayo
# 2 aha
# 1 ahca
# 1 ahead
# 2 ahu
# 1 aia
# 5 aid
# 12 aide
# 6 aides
# 2 aids
# 1 ailment
# 2 aim
# 1 aiming
# 2 air
# 2 airport
# 6 ais
# 3 ait
# 1 aitkin
# 3 aj
# 1 ajax
# 1 ak
# 2 akin
# 2 akron
# 4 al
# 22 alabama
# 1 alarmed
# 1 alaska
# 2 albanian
# 1 albertville
# 1 albums
# 4 albuquerque
# 1 alcohol
# 1 alene
# 1 alert
# 1 alerts
# 1 alertss
# 3 alexandria
# 1 alfred
# 2 all
# 3 alla
# 6 allen
# 2 allergies
# 8 allergy
# 9 alliance
# 1 allogeneic
# 5 allow
# 1 allowances
# 5 allowed
# 6 allowing
# 5 allows
# 31 almh
# 1 almond
# 6 almost
# 3 alone
# 12 along
# 1 alongside
# 1 alphabetically
# 3 already
# 62 also
# 1 alt
# 2 alterg
# 1 alternate
# 1 alternatives
# 9 although
# 1 altus
# 2 alumni
# 1 alvin
# 26 always
# 23 alzheimer
# 2 am
# 1 amanda
# 1 amazing
# 1 ambulance
# 2 ambulatory
# 29 amenities
# 1 amenity
# 1 ameravant
# 21 america
# 53 american
# 3 americaneagle
# 3 americans
# 1 americinn
# 2 americorps
# 3 amet
# 1 ami
# 1 amidst
# 22 among
# 1 amory
# 1 amos
# 2 amount
# 1 amp
# 2 amy
# 1 ana
# 12 anacortes
# 1 analysts
# 3 analytics
# 2 analyzed
# 1 analyzes
# 1 anamaria
# 1 anania
# 3 anatomic
# 1 anatomy
# 2 and
# 1 andalusia
# 5 anderson
# 1 andes
# 3 andover
# 4 andrew
# 1 anemia
# 8 anesthesia
# 1 anesthesiologist
# 12 anesthesiology
# 2 anesthetist
# 1 anesthetists
# 1 aneurysms
# 2 anew
# 1 angela
# 2 angeles
# 1 angell
# 5 angelo
# 1 angels
# 2 angie
# 1 angina
# 1 angles
# 4 ankle
# 1 ankles
# 2 ann
# 2 annandale
# 3 anne
# 1 anniston
# 3 anniversary
# 10 announce
# 7 announced
# 2 announcements
# 2 announcing
# 28 annual
# 2 annually
# 3 anonymous
# 8 another
# 1 anp
# 8 answer
# 2 answers
# 1 ante
# 1 anterior
# 1 anthem
# 3 anti
# 1 antiaging
# 1 antibiotics
# 1 anticipating
# 1 anticipation
# 3 anticoagulation
# 1 antifungal
# 3 antioch
# 1 antipsychotics
# 1 antiques
# 1 antonio
# 1 anxiety
# 5 anyone
# 1 anything
# 1 anytime
# 6 apartment
# 3 apartments
# 1 api
# 2 aplushhh
# 1 apologize
# 1 apopka
# 5 app
# 1 apparel
# 1 apparent
# 4 appeal
# 1 appetizer
# 4 appetizers
# 1 appetizing
# 1 apple
# 1 apples
# 1 appliances
# 1 applicable
# 3 applicants
# 21 application
# 6 applications
# 1 applied
# 2 applies
# 21 apply
# 2 applying
# 4 appointed
# 35 appointment
# 10 appointments
# 1 appraisals
# 3 appreciation
# 11 approach
# 1 approaches
# 4 appropriate
# 6 approval
# 3 approved
# 7 approximately
# 1 apps
# 35 april
# 1 aquarium
# 6 aquatic
# 1 aquatics
# 2 ar
# 2 arabic
# 2 arbor
# 1 arboretum
# 1 architect
# 10 archive
# 8 archives
# 1 arcu
# 60 area
# 39 areas
# 1 arena
# 3 arizona
# 1 ark
# 6 arkansas
# 3 arlene
# 3 arlington
# 1 arm
# 1 armenian
# 2 armoires
# 1 armour
# 2 arms
# 1 arnold
# 15 around
# 2 arrange
# 1 arranged
# 1 arrangement
# 2 arrangements
# 6 array
# 1 arrhythmias
# 1 arrhythmics
# 2 arrival
# 2 arrive
# 1 arrives
# 1 arriving
# 1 arrowood
# 1 arrowwood
# 23 art
# 1 arteries
# 1 artery
# 1 arthritis
# 1 arthur
# 6 article
# 9 articles
# 1 artifical
# 1 artificial
# 9 arts
# 4 artwork
# 1 arugula
# 1 asap
# 11 asheville
# 1 ashevilleart
# 1 ashevilletheatre
# 2 ashland
# 1 ashley
# 2 asian
# 16 ask
# 14 asked
# 1 asking
# 1 aspect
# 5 aspects
# 12 aspen
# 1 aspx
# 2 assess
# 1 assessed
# 1 assesses
# 1 assessing
# 44 assessment
# 5 assessments
# 1 asset
# 2 assign
# 2 assigns
# 10 assist
# 96 assistance
# 18 assistant
# 6 assistants
# 56 assisted
# 1 assisting
# 2 assists
# 5 associate
# 7 associated
# 9 associates
# 54 association
# 2 associations
# 1 assorted
# 1 assumed
# 4 assurance
# 2 assure
# 1 assured
# 5 aster
# 3 asthma
# 1 astounding
# 1 asusu
# 2 at
# 1 atchison
# 1 athens
# 1 atherosclerosis
# 1 athlete
# 2 athletes
# 4 athletic
# 1 atient
# 13 atlanta
# 1 atlantasky
# 2 atm
# 11 atmosphere
# 1 atms
# 1 attached
# 1 attachment
# 6 attack
# 1 attacks
# 2 attain
# 1 attained
# 1 attaining
# 2 attend
# 1 attendants
# 3 attended
# 6 attending
# 6 attention
# 1 attentive
# 1 attitude
# 1 attitudes
# 9 attractions
# 1 attributes
# 1 attuned
# 2 atwell
# 5 auction
# 9 audiology
# 1 auditor
# 1 audits
# 1 augue
# 29 august
# 1 augusta
# 1 aunt
# 1 austinown
# 1 austintown
# 1 author
# 1 authored
# 4 authority
# 3 authorization
# 2 autism
# 1 auto
# 2 autographed
# 1 autologous
# 2 automated
# 1 automotive
# 11 auxiliary
# 4 availability
# 54 available
# 2 avatar
# 10 ave
# 15 avenue
# 15 avera
# 19 average
# 11 averages
# 1 averanow
# 4 avh
# 3 avid
# 1 avocado
# 2 avoid
# 4 avon
# 118 award
# 26 awarded
# 64 awards
# 1 awared
# 8 awareness
# 5 away
# 1 awhile
# 2 ayisyen
# 1 ayobami
# 5 az
# 1 azerbaijani
# 1 ba
# 3 babies
# 11 baby
# 1 bacara
# 9 bachelor
# 2 bachelors
# 48 back
# 1 background
# 1 backstreet
# 2 backyard
# 1 bacteria
# 2 bad
# 1 bag
# 1 baggies
# 1 bahamas
# 1 bailey
# 1 baker
# 6 balance
# 1 baldwin
# 2 ball
# 1 balloon
# 1 ballots
# 3 balls
# 1 ballston
# 1 balm
# 4 baltimore
# 1 band
# 6 bank
# 15 baptist
# 4 bar
# 2 baraboo
# 25 barbara
# 3 barber
# 9 bariatric
# 3 bariatrics
# 1 barre
# 1 barrie
# 1 barry
# 1 barstock
# 4 barton
# 1 base
# 3 baseball
# 1 basecamp
# 51 based
# 1 baseline
# 2 basic
# 1 basically
# 11 basis
# 13 basket
# 1 basque
# 5 bass
# 11 bassett
# 3 bate
# 2 bath
# 7 bathing
# 2 bathrooms
# 2 baths
# 1 baton
# 1 battle
# 4 baxter
# 8 bay
# 2 baylor
# 2 bayside
# 3 bbq
# 1 bc
# 2 bcmh
# 4 beach
# 3 beal
# 1 bear
# 2 beat
# 1 beaudette
# 9 beautiful
# 4 beauty
# 5 became
# 1 beck
# 4 becker
# 16 become
# 3 becomes
# 30 bed
# 1 bedford
# 3 bedroom
# 1 bedrooms
# 19 beds
# 4 bedside
# 2 bedspreads
# 1 beef
# 1 beer
# 11 began
# 16 begin
# 4 beginning
# 2 beginnings
# 5 begins
# 24 behavioral
# 5 behaviors
# 2 behind
# 4 being
# 2 belarusian
# 1 belief
# 2 beliefs
# 8 believe
# 1 believes
# 2 belle
# 2 bellefonte
# 1 belmont
# 1 belongings
# 1 belt
# 1 beltway
# 1 benaroya
# 1 bench
# 1 benchmarking
# 4 benchmarks
# 2 beneficial
# 25 benefit
# 2 benefited
# 34 benefits
# 1 bennett
# 3 benson
# 4 bereavement
# 4 berkshire
# 1 berlin
# 1 bernardine
# 2 berry
# 94 best
# 1 bestowed
# 1 beta
# 1 bethanie
# 1 bethesda
# 24 better
# 1 betterment
# 5 beverage
# 2 beverages
# 1 beverly
# 4 beyond
# 1 beyondnow
# 3 bhc
# 1 bhsh
# 1 bibendum
# 1 bible
# 1 bids
# 10 big
# 11 bigfork
# 1 bigforkvalley
# 1 biggs
# 1 bike
# 1 biliary
# 98 bill
# 44 billing
# 1 billpay
# 7 biltmore
# 2 biodex
# 1 biographies
# 2 biography
# 3 biology
# 5 biopsy
# 2 bios
# 1 birgit
# 15 birth
# 1 birthdays
# 9 birthing
# 4 birthplace
# 1 births
# 1 bisexual
# 1 bittersweet
# 1 bizaad
# 7 bjc
# 1 bjerkness
# 33 black
# 2 blackburn
# 1 blackmon
# 1 blackwelder
# 2 bladder
# 3 blanchette
# 3 blanding
# 1 blank
# 1 blast
# 1 blessed
# 1 blind
# 2 blint
# 2 block
# 2 blocked
# 32 blog
# 1 blognvna
# 3 blogs
# 43 blood
# 1 bloodless
# 18 blue
# 1 blueridgeparkway
# 10 bluff
# 4 blvd
# 4 blytheville
# 1 bmc
# 1 bmf
# 2 bmh
# 1 bmhutah
# 85 board
# 3 boardman
# 3 boards
# 1 boasts
# 2 boat
# 1 boaters
# 2 bob
# 2 bobbers
# 2 boca
# 1 bod
# 9 body
# 2 bohemian
# 1 bohemianhotelasheville
# 1 boiled
# 1 bold
# 1 bomgar
# 14 bon
# 1 bond
# 12 bone
# 2 bonita
# 2 book
# 2 books
# 35 boone
# 1 boost
# 3 bootstrap
# 1 border
# 1 borders
# 1 boredom
# 1 borja
# 2 born
# 3 boston
# 1 botsford
# 3 bottle
# 4 bottles
# 4 bottom
# 1 bought
# 1 boulder
# 2 boulevard
# 1 bound
# 1 boushay
# 3 boutique
# 1 bowel
# 1 bowl
# 2 bowling
# 1 bowman
# 12 box
# 2 boxes
# 1 boynton
# 2 boys
# 1 bpass
# 1 bph
# 1 br
# 1 bracelet
# 1 bradenton
# 1 bradley
# 8 brain
# 6 brainerd
# 1 braintree
# 13 branch
# 7 branches
# 1 brand
# 2 brandel
# 1 brandon
# 1 brave
# 3 breadcrumb
# 1 breadcrumbs
# 1 breads
# 7 break
# 4 breakfast
# 35 breast
# 1 breastfeeding
# 1 breath
# 1 breathe
# 2 breathing
# 2 breezy
# 3 brent
# 3 brentwood
# 1 brewing
# 3 brick
# 2 bridge
# 1 bright
# 1 brighten
# 1 brightens
# 1 brighton
# 7 bring
# 2 bringing
# 6 brings
# 1 brinker
# 2 bristol
# 1 brits
# 3 broad
# 2 broader
# 1 broadway
# 1 brochure
# 1 brochures
# 1 brock
# 1 broil
# 5 bronze
# 1 brookfield
# 7 brooklyn
# 1 brooks
# 2 brooten
# 1 brought
# 3 brouse
# 2 broward
# 10 brown
# 3 browser
# 1 bruce
# 1 brumfield
# 2 brunch
# 1 brunswick
# 1 brush
# 1 brushed
# 1 brushfire
# 1 brutal
# 1 bryant
# 1 bryner
# 1 bs
# 5 bsmc
# 6 bsn
# 1 buchsbaum
# 1 bud
# 3 buddy
# 1 buffet
# 1 buffett
# 6 build
# 3 builder
# 21 building
# 4 buildings
# 2 builds
# 6 built
# 2 bulgarian
# 1 bulk
# 1 bundled
# 2 burdett
# 3 bureau
# 1 bureaucracy
# 1 burger
# 1 burlington
# 2 burn
# 1 burton
# 1 bus
# 22 business
# 1 businesses
# 2 busting
# 3 busy
# 3 button
# 1 buy
# 1 bvactive
# 1 by
# 1 bypass
# 1 byron
# 12 ca
# 1 cabarrus
# 1 cabin
# 1 cabinets
# 3 cable
# 9 caf
# 4 cafe
# 18 cafeteria
# 4 cahps
# 2 calais
# 2 calcium
# 3 calculate
# 2 calculated
# 1 calculating
# 1 calculator
# 38 calendar
# 1 calendars
# 1 calender
# 1 calhoun
# 1 caliber
# 1 calif
# 21 california
# 71 call
# 6 called
# 4 calling
# 3 calloway
# 1 calm
# 1 calming
# 1 calorie
# 5 calories
# 1 calqualitycare
# 6 came
# 5 campaign
# 24 campbell
# 1 camping
# 25 campus
# 6 canadian
# 1 canajoharie
# 2 cancel
# 1 cancelled
# 98 cancer
# 3 cancercenter
# 5 cancers
# 1 candidates
# 2 canfield
# 2 cannot
# 5 canterbury
# 4 cap
# 1 capability
# 3 capacity
# 1 capd
# 2 cape
# 7 capital
# 1 car
# 22 card
# 29 cardiac
# 2 cardio
# 2 cardiologist
# 34 cardiology
# 1 cardiomyopathy
# 5 cardiopulmonary
# 4 cardiothoracic
# 1 cardiothoracicvascular
# 29 cardiovascular
# 1 cardon
# 6 cards
# 1132 care
# 4 cared
# 1 careemploymentcontact
# 25 career
# 148 careers
# 1 careful
# 4 carefully
# 17 caregiver
# 27 caregivers
# 1 caregiving
# 1 carelaboratoryclinicprovidersradiologyabout
# 1 carelink
# 1 carepartners
# 2 cares
# 4 carf
# 1 caribbean
# 1 caribou
# 35 caring
# 4 caringbridge
# 2 carlisle
# 2 carlsbad
# 1 carlton
# 3 carol
# 5 carolina
# 18 carolinas
# 1 carpenter
# 1 carpet
# 3 carried
# 1 carrier
# 1 carroll
# 2 cart
# 13 carter
# 1 carterhealthcare
# 1 carver
# 2 cary
# 3 casa
# 3 cascade
# 10 case
# 3 cases
# 1 cashier
# 3 casino
# 1 castle
# 1 castleton
# 2 castleview
# 1 casts
# 2 catalan
# 1 cataract
# 2 catch
# 2 catching
# 15 categories
# 1 categorized
# 10 category
# 8 catholic
# 7 cause
# 2 caused
# 2 causes
# 12 cch
# 1 cchcf
# 2 cchwyo
# 1 ccloginlink
# 2 ccmg
# 1 ccmh
# 1 ccpd
# 6 ccrc
# 1 cd
# 1 cdc
# 44 cdf
# 29 cdv
# 1 cecil
# 3 celebrated
# 5 celebrates
# 2 celebrating
# 2 celebration
# 1 celebrations
# 1 celebrity
# 4 cell
# 2 cellular
# 4 census
# 1 centenarian
# 531 center
# 12 centered
# 1 centeredness
# 88 centers
# 32 central
# 2 centro
# 26 ceo
# 1 ceramic
# 1 cereal
# 1 cerebrovascular
# 2 ceremony
# 2 cerner
# 8 certain
# 1 certainly
# 26 certificate
# 13 certificates
# 16 certification
# 7 certifications
# 57 certified
# 3 certifies
# 4 cessation
# 1 cfr
# 1 cfre
# 1 chadi
# 2 chaffee
# 1 chahta
# 4 chair
# 2 chairman
# 4 chairs
# 1 chalet
# 5 challenge
# 3 challenges
# 4 challenging
# 3 chamber
# 1 champion
# 2 chance
# 1 chang
# 14 change
# 3 changed
# 6 changes
# 2 changing
# 2 chanhassen
# 3 channel
# 5 chap
# 3 chapel
# 6 chaplain
# 1 chaplains
# 3 chapter
# 1 char
# 1 character
# 1 characteristic
# 1 characteristics
# 4 charge
# 3 charges
# 5 charitable
# 3 charities
# 4 charity
# 1 charles
# 2 charleston
# 5 charlotte
# 1 charm
# 1 charms
# 5 chart
# 2 charter
# 1 chartlink
# 16 chat
# 2 che
# 9 check
# 1 checked
# 1 checking
# 1 checklist
# 1 checks
# 2 checkup
# 1 chee
# 1 cheeks
# 1 cheese
# 1 cheeseburger
# 3 chef
# 1 chefs
# 2 chemical
# 2 chemotherapy
# 1 cher
# 1 cherished
# 1 cherry
# 1 cherryberry
# 2 chesapeake
# 1 cheslek
# 6 chest
# 1 chesterfield
# 1 cheveux
# 2 cheyenne
# 4 chfs
# 9 chicago
# 2 chicken
# 6 chicopee
# 10 chief
# 12 chien
# 41 child
# 11 childbirth
# 1 childcare
# 1 childcontent
# 39 children
# 1 chilled
# 3 chinese
# 1 chip
# 4 chippewa
# 3 chips
# 4 chiropractic
# 2 chiropractor
# 1 chna
# 3 chocolate
# 2 choctaw
# 25 choice
# 12 choices
# 1 cholesterol
# 24 choose
# 13 choosing
# 1 choreomedia
# 3 chose
# 5 chosen
# 1 chris
# 2 christ
# 1 christi
# 3 christina
# 4 christmas
# 3 christopher
# 49 christus
# 1 christy
# 13 chronic
# 1 chs
# 1 chunk
# 2 church
# 1 churches
# 1 cicbc
# 1 cigna
# 2 cilantro
# 1 cindy
# 3 circle
# 1 circuit
# 1 circular
# 3 circumstances
# 1 citations
# 1 citehealth
# 1 cities
# 4 citizens
# 2 citrix
# 34 city
# 3 civic
# 2 civil
# 1 cjr
# 1 ckd
# 3 claims
# 2 claire
# 2 clam
# 1 clanton
# 3 claremont
# 1 clarity
# 2 clark
# 3 clarke
# 22 class
# 60 classes
# 1 classic
# 1 classroom
# 1 clc
# 3 clean
# 1 cleanest
# 1 cleaning
# 7 cleanliness
# 1 cleanser
# 2 clear
# 1 clearly
# 1 clerical
# 5 cleveland
# 1 clh
# 30 click
# 5 clicking
# 1 clicks
# 6 client
# 9 clients
# 1 clientscripts
# 1 cliff
# 3 climate
# 1 clinard
# 2 clindesk
# 156 clinic
# 109 clinical
# 3 clinician
# 3 clinicians
# 53 clinics
# 1 clinton
# 2 clock
# 1 clocktower
# 16 close
# 8 closed
# 3 closely
# 1 closes
# 1 closets
# 4 closing
# 2 closings
# 2 clothing
# 1 clots
# 13 club
# 2 clubhouse
# 1 cmckinney
# 5 cme
# 85 cms
# 6 cna
# 1 cne
# 3 cnml
# 2 cnor
# 7 co
# 1 coa
# 2 coaching
# 1 coagulation
# 1 coalition
# 1 coap
# 3 coast
# 1 coastal
# 1 coat
# 1 coats
# 4 cobleskill
# 1 cochlear
# 2 cochran
# 1 coconut
# 23 code
# 2 codes
# 1 coeur
# 9 coffee
# 1 coffees
# 3 cognitive
# 1 cohasset
# 7 col
# 1 colada
# 1 colbath
# 1 coleman
# 2 colfax
# 1 collaborates
# 2 collaboration
# 1 collaborative
# 4 collapse
# 1 colleagues
# 1 collect
# 3 collected
# 1 collecting
# 5 collection
# 1 collectors
# 3 collects
# 26 college
# 3 colleges
# 1 collier
# 1 collin
# 4 collins
# 2 colon
# 1 colona
# 4 colonoscopy
# 7 color
# 2 colorado
# 2 colorectal
# 2 colors
# 1 colsen
# 9 columbia
# 14 columbus
# 7 column
# 1 columns
# 49 com
# 2 combination
# 2 combine
# 8 combined
# 4 combines
# 2 combo
# 1 comcast
# 16 come
# 6 comes
# 16 comfort
# 22 comfortable
# 1 comfortably
# 1 comforting
# 1 comforts
# 3 coming
# 1 commemorate
# 1 commendation
# 1 commended
# 1 commends
# 5 comment
# 2 commented
# 12 comments
# 3 commerce
# 5 commercial
# 1 commercials
# 70 commission
# 5 commissioners
# 2 commit
# 27 commitment
# 2 commitments
# 19 committed
# 7 committee
# 1 committees
# 14 common
# 1 commonly
# 1 commons
# 1 commonwealth
# 3 communicate
# 3 communicated
# 2 communicates
# 1 communicating
# 13 communication
# 5 communications
# 28 communities
# 311 community
# 3 companies
# 2 companion
# 1 companionship
# 42 company
# 3 comparative
# 56 compare
# 5 compared
# 1 compares
# 4 comparing
# 5 comparison
# 1 comparisons
# 12 compassion
# 19 compassionate
# 3 compensation
# 5 competent
# 1 competition
# 3 competitive
# 1 complaint
# 3 complaints
# 1 complement
# 1 complements
# 19 complete
# 14 completed
# 3 completely
# 2 completes
# 1 completing
# 1 completion
# 2 complex
# 1 complexes
# 11 compliance
# 1 complication
# 1 complies
# 1 complimentary
# 5 components
# 1 composed
# 3 composite
# 20 comprehensive
# 1 comprise
# 2 comprised
# 1 comprises
# 1 compromise
# 3 computed
# 4 computer
# 1 computers
# 1 coms
# 1 conainer
# 1 concentration
# 2 concept
# 6 concern
# 3 concerned
# 6 concerns
# 3 concierge
# 1 concoction
# 1 concrete
# 4 concussion
# 9 condition
# 1 conditioner
# 19 conditions
# 4 conduct
# 3 conducted
# 1 conducting
# 5 conference
# 1 conferences
# 1 confidence
# 2 confidentiality
# 1 confirmation
# 1 confirmed
# 1 confronted
# 1 confusing
# 2 congenital
# 2 congestive
# 2 congratulations
# 3 congregate
# 1 congregational
# 1 congress
# 2 conjunction
# 12 connect
# 4 connected
# 1 connecticut
# 1 connecting
# 5 connection
# 6 connections
# 3 connor
# 1 conscientious
# 1 conscious
# 1 consectetuer
# 1 consectetur
# 14 consecutive
# 1 consent
# 1 conservation
# 2 conserve
# 4 consider
# 1 considerable
# 1 consideration
# 1 considerations
# 5 considered
# 1 consistency
# 3 consistent
# 17 consistently
# 1 consisting
# 4 consists
# 2 consortium
# 3 constantly
# 1 constellation
# 2 constructed
# 5 construction
# 1 consult
# 1 consultants
# 1 consultation
# 2 consultations
# 1 consulting
# 16 consumer
# 17 consumers
# 1 consuming
# 289 contact
# 1 contacted
# 1 contacts
# 2 contagious
# 11 container
# 3 containers
# 1 contains
# 1 contemplative
# 31 content
# 1 contina
# 2 continence
# 1 continental
# 2 continual
# 4 continually
# 1 continuation
# 21 continue
# 4 continued
# 3 continues
# 17 continuing
# 1 continuity
# 1 continuous
# 5 continuum
# 2 contract
# 3 contracted
# 1 contracting
# 2 contractor
# 3 contribute
# 2 contributed
# 1 contributes
# 2 contributing
# 1 contribution
# 2 contributions
# 1 contributor
# 11 control
# 2 controlled
# 1 controversies
# 8 convalescent
# 1 convallis
# 6 convenience
# 9 convenient
# 4 conveniently
# 1 convent
# 2 convention
# 4 conversation
# 1 converted
# 7 cook
# 2 cookbook
# 2 cookbooks
# 1 cookie
# 1 cookies
# 6 cooking
# 1 cookouts
# 1 cooler
# 1 cooley
# 1 coon
# 1 cooper
# 1 cooperation
# 1 cooperative
# 3 cooperstown
# 1 coordinate
# 3 coordinated
# 1 coordinating
# 18 coordinator
# 1 coordinators
# 2 coozies
# 2 copy
# 33 copyright
# 5 cor
# 1 cord
# 1 cordarrelle
# 1 cordell
# 12 core
# 1 corn
# 1 cornea
# 1 coronary
# 1 corp
# 1 corpcomm
# 14 corporate
# 7 corporation
# 1 correct
# 1 correctly
# 1 correlated
# 3 cosmetic
# 1 cosmo
# 8 cost
# 1 costs
# 1 costumes
# 32 cottage
# 1 cottages
# 1 cottonwood
# 6 could
# 1 coumadin
# 6 council
# 3 counsel
# 8 counseling
# 1 counselor
# 2 counselors
# 5 count
# 9 counties
# 1 counting
# 1 countries
# 17 country
# 1 countryside
# 83 county
# 1 couple
# 1 courage
# 1 courageous
# 1 courier
# 5 course
# 2 courses
# 2 court
# 1 courteous
# 1 courtesy
# 1 courtyard
# 3 courtyards
# 1 covenant
# 5 cover
# 11 coverage
# 4 covered
# 3 covers
# 1 covington
# 3 cowley
# 2 cozy
# 1 cp
# 1 cpcs
# 1 cphrm
# 1 cpmsm
# 3 cpr
# 8 cpsys
# 1 cr
# 1 crackers
# 1 craft
# 1 crafted
# 2 crafts
# 2 cragun
# 6 craig
# 1 craniofacial
# 5 crawford
# 1 crayola
# 5 cream
# 1 creamy
# 18 create
# 8 created
# 9 creating
# 3 creative
# 3 credentialing
# 5 credentials
# 1 credible
# 2 credit
# 1 credits
# 5 creek
# 1 creeks
# 2 creole
# 1 crest
# 1 crisis
# 1 crisp
# 1 cristo
# 5 criteria
# 25 critical
# 1 critically
# 3 crmc
# 1 crna
# 2 croatian
# 3 cros
# 5 crosby
# 6 cross
# 15 crossing
# 3 crosslake
# 1 crosswoods
# 1 crow
# 1 cruise
# 1 crusius
# 2 cruz
# 4 crystal
# 1 cscs
# 47 css
# 15 ct
# 2 cta
# 14 ctca
# 1 cuervo
# 9 culinary
# 1 cullman
# 3 cultural
# 8 culture
# 1 culver
# 1 cumming
# 1 cummings
# 1 cumulative
# 1 cunningham
# 1 cupcake
# 1 cupcakes
# 1 curious
# 2 curling
# 20 current
# 7 currently
# 2 curriculum
# 2 curtains
# 9 custom
# 6 customer
# 1 customizable
# 1 customize
# 2 customized
# 4 cut
# 5 cutting
# 4 cuyuna
# 1 cuyunamed
# 1 cycle
# 1 cynthia
# 1 cystitis
# 1 cystocele
# 2 cystoscopy
# 1 cytogenetics
# 2 cytopathology
# 2 czech
# 1 da
# 1 dad
# 2 dade
# 1 dadra
# 1 dahal
# 21 daily
# 1 daise
# 6 dakota
# 2 dale
# 6 dallas
# 2 damage
# 1 dan
# 2 danish
# 1 dare
# 2 dashboard
# 29 data
# 2 database
# 7 date
# 1 dates
# 3 daughters
# 1 dave
# 3 david
# 1 davidson
# 1 davie
# 20 davita
# 2 dawn
# 90 day
# 1 daylight
# 28 days
# 2 dayton
# 1 daytona
# 2 dba
# 6 dc
# 8 dch
# 1 dd
# 7 de
# 1 deadliest
# 1 deal
# 2 dealing
# 2 dean
# 2 dear
# 4 death
# 1 debbi
# 1 debbie
# 1 debilitating
# 3 dec
# 1 decade
# 1 decadent
# 28 december
# 1 decesare
# 4 decide
# 1 decided
# 1 decides
# 8 decision
# 11 decisions
# 1 deck
# 1 decontamination
# 1 decorated
# 2 decrease
# 3 decreasing
# 1 decubitus
# 28 dedicated
# 10 dedication
# 2 deductible
# 1 deemed
# 1 deeming
# 1 deep
# 1 deerstand
# 4 deerwood
# 12 default
# 1 defense
# 1 deficiencies
# 3 deficiency
# 2 defined
# 2 defines
# 5 definition
# 1 degraaf
# 16 degree
# 5 degrees
# 2 deitsch
# 3 dekalb
# 3 del
# 1 deland
# 1 delanson
# 2 delaware
# 2 delays
# 1 delegating
# 1 delhi
# 1 delicate
# 8 delicious
# 1 delights
# 14 deliver
# 7 delivered
# 5 delivering
# 5 delivers
# 9 delivery
# 1 delta
# 1 delton
# 1 demands
# 16 dementia
# 2 dementias
# 1 dementing
# 1 demographics
# 1 demonstrably
# 1 demonstrate
# 1 demonstrated
# 1 demonstrating
# 1 demonstration
# 1 den
# 4 denise
# 1 denison
# 1 denny
# 1 denominational
# 1 denotes
# 3 densitometry
# 5 density
# 9 dental
# 1 dentist
# 9 dentistry
# 1 denton
# 1 deny
# 54 department
# 2 departmental
# 13 departments
# 2 depend
# 1 dependence
# 2 dependent
# 1 depending
# 1 deposits
# 1 depression
# 1 dept
# 1 depth
# 1 derechos
# 1 dermablade
# 11 dermatology
# 2 dermatopathology
# 1 described
# 2 describes
# 5 deserve
# 2 deserved
# 1 deserves
# 27 design
# 7 designated
# 17 designation
# 3 designations
# 22 designed
# 1 designing
# 1 designs
# 2 desire
# 2 desk
# 2 desktop
# 1 desktopmodules
# 2 despair
# 1 despite
# 1 dessert
# 1 desserts
# 1 destination
# 2 det
# 1 detail
# 3 detailed
# 7 details
# 2 detailsfootercontent
# 2 detailsheadercontent
# 1 deter
# 3 determine
# 1 determined
# 2 detox
# 1 detroit
# 6 deutsch
# 1 deutsche
# 6 develop
# 6 developed
# 18 development
# 4 developmental
# 2 develops
# 1 device
# 3 devices
# 1 devise
# 1 devoted
# 1 devotion
# 3 dexa
# 1 dfw
# 37 diabetes
# 2 diabetic
# 4 diagnose
# 1 diagnoses
# 5 diagnosis
# 22 diagnostic
# 21 diagnostics
# 1 dialogue
# 48 dialysis
# 1 dialyzer
# 1 dialyzing
# 1 diamante
# 1 diamond
# 1 diane
# 1 diathermy
# 2 dick
# 3 dickson
# 1 dictionary
# 1 diego
# 9 diet
# 7 dietary
# 1 dietician
# 4 dietitian
# 2 dietitians
# 1 diets
# 1 differ
# 16 difference
# 1 differences
# 10 different
# 1 differentiated
# 7 difficult
# 1 digest
# 8 digestive
# 2 digg
# 10 digital
# 1 dignitaries
# 11 dignity
# 1 dignityhealth
# 1 diligently
# 1 dill
# 1 dimension
# 2 dimensions
# 1 diminish
# 1 diminished
# 1 din
# 39 dining
# 8 dinner
# 1 dinners
# 2 dip
# 2 direct
# 2 directed
# 5 direction
# 78 directions
# 2 directive
# 15 directives
# 7 directly
# 46 director
# 26 directors
# 19 directory
# 1 directs
# 2 disabilities
# 9 disability
# 6 disabled
# 1 disappointed
# 2 disaster
# 1 discernment
# 17 discharge
# 2 discharged
# 14 disclaimer
# 1 disclose
# 3 disclosure
# 1 discounts
# 4 discover
# 1 discovery
# 1 discriminaci
# 3 discriminate
# 13 discrimination
# 3 discuss
# 2 discussion
# 62 disease
# 5 diseases
# 3 disorder
# 29 disorders
# 2 disparities
# 1 dispatch
# 1 dispensation
# 1 dispenser
# 1 dispensers
# 1 display
# 1 displays
# 1 disposible
# 1 disrupted
# 2 distance
# 1 distances
# 2 distinct
# 19 distinction
# 1 distinguish
# 1 distribution
# 14 district
# 2 div
# 3 diverse
# 1 diversification
# 2 diversified
# 6 diversity
# 1 diversityinc
# 5 division
# 1 divisional
# 1 dme
# 9 dnn
# 2 dnncore
# 1 dnncorp
# 2 dnndefault
# 2 dnnmega
# 1 dnp
# 1 dns
# 2 dnv
# 1 dockside
# 1 docs
# 82 doctor
# 1 doctorate
# 19 doctors
# 1 document
# 1 documentation
# 8 documents
# 1 dolgeville
# 2 dollars
# 2 dolor
# 1 dolphin
# 5 dominican
# 23 donate
# 1 donated
# 17 donation
# 10 donations
# 1 dondelinger
# 6 done
# 1 donec
# 6 donor
# 3 donors
# 1 door
# 4 doors
# 1 dore
# 1 dose
# 12 dosher
# 1 dothan
# 1 doubles
# 2 douglas
# 1 dousman
# 1 down
# 7 download
# 2 downloadable
# 1 downloaded
# 1 downloads
# 5 downtown
# 1 dozens
# 1 dpt
# 57 dr
# 1 drawn
# 2 draws
# 3 dream
# 1 dreamed
# 2 dresser
# 1 dressign
# 6 dressing
# 2 dressings
# 1 drill
# 1 drink
# 1 drinker
# 4 drinks
# 19 drive
# 5 driven
# 1 drivers
# 4 drives
# 12 driving
# 2 drone
# 1 dropdown
# 4 drug
# 5 drugs
# 1 drunk
# 2 dsc
# 4 dtw
# 13 du
# 2 dually
# 1 ductography
# 7 due
# 2 dull
# 2 dunes
# 6 dunkirk
# 1 dunmore
# 1 dupage
# 4 durable
# 1 durand
# 1 dusting
# 3 dutch
# 3 duties
# 3 duty
# 1 duxbury
# 1 dv
# 1 dvd
# 2 dying
# 1 dynamic
# 1 dynamicnavigation
# 1 dystrophy
# 2 eads
# 9 eagle
# 2 eagles
# 1 eap
# 9 ear
# 1 earl
# 2 earlier
# 1 earlville
# 11 early
# 7 earn
# 26 earned
# 6 earning
# 16 earns
# 5 ease
# 11 easier
# 8 easily
# 31 east
# 2 eastern
# 1 eastside
# 14 easy
# 3 eat
# 1 eaten
# 1 eatery
# 5 eating
# 1 ebert
# 3 ecard
# 1 ecards
# 1 ecare
# 1 ecclesial
# 1 echo
# 2 eckrich
# 1 eclectic
# 2 ecommunity
# 2 economic
# 1 economy
# 7 edge
# 40 edgewood
# 1 edition
# 1 editorial
# 2 edmeston
# 12 edmond
# 1 edt
# 2 educate
# 78 education
# 9 educational
# 1 edward
# 3 effect
# 1 effecting
# 10 effective
# 1 effectively
# 1 effectiveness
# 1 effects
# 5 efficiency
# 5 efficient
# 2 efficiently
# 2 effie
# 11 effort
# 12 efforts
# 1 eget
# 1 eggs
# 1 egreeting
# 7 eight
# 1 eighteen
# 2 eighth
# 1 eileen
# 3 either
# 1 eiusmod
# 2 el
# 1 elaine
# 1 elbow
# 2 elder
# 2 eldercare
# 13 elderly
# 1 eldest
# 3 elected
# 1 election
# 1 electric
# 1 electrical
# 1 electrocardiograms
# 3 electronic
# 2 electronically
# 2 electrophysiology
# 5 elegant
# 1 elementary
# 1 elevators
# 2 eleven
# 2 eligibility
# 8 eligible
# 2 eliminate
# 1 eliminated
# 2 elit
# 12 elite
# 5 ellen
# 1 elliott
# 1 elm
# 1 elnec
# 1 elroy
# 3 else
# 1 elyria
# 55 email
# 1 emails
# 1 embarked
# 1 embarrassment
# 1 embrace
# 2 emerald
# 1 emergencies
# 97 emergency
# 2 emery
# 1 emily
# 1 emory
# 4 emotional
# 2 emotionally
# 2 emphasis
# 1 emphasize
# 2 employ
# 2 employed
# 42 employee
# 41 employees
# 7 employer
# 5 employers
# 41 employment
# 1 employs
# 3 empower
# 1 empowered
# 2 empowering
# 1 empowers
# 1 emr
# 2 ems
# 6 en
# 3 enable
# 3 enabled
# 1 enables
# 1 enabling
# 1 enclosed
# 1 encompassing
# 1 encounter
# 1 encountered
# 7 encourage
# 6 encouraged
# 1 encouragement
# 2 encourages
# 2 encouraging
# 1 encrypted
# 46 end
# 1 ending
# 2 endocrine
# 15 endocrinology
# 1 endorse
# 1 endoscopic
# 6 endoscopy
# 1 endovascular
# 1 enduring
# 1 energized
# 6 energy
# 3 enews
# 3 enewsletter
# 5 enewsletters
# 1 enforces
# 2 engage
# 3 engaged
# 3 engagement
# 1 engaging
# 1 engebrecht
# 2 engineering
# 1 engineers
# 4 england
# 8 english
# 5 enhance
# 4 enhanced
# 3 enhancement
# 2 enhances
# 4 enhancing
# 4 enid
# 16 enjoy
# 2 enjoyed
# 4 enjoying
# 2 enjoys
# 1 enlarge
# 2 enlarged
# 2 ennis
# 1 eno
# 4 enough
# 1 enrich
# 1 enriching
# 3 enrichment
# 3 enroll
# 1 enrolled
# 2 enrolling
# 4 enrollment
# 8 ensure
# 4 ensuring
# 5 ent
# 9 enter
# 3 enteral
# 3 entered
# 3 enterprise
# 1 entertainer
# 1 entertaining
# 2 entertainment
# 1 enticement
# 11 entire
# 2 entities
# 2 entitled
# 2 entity
# 5 entrance
# 2 entrances
# 1 entree
# 1 entrepreneurial
# 1 entries
# 1 entrusted
# 1 entry
# 30 environment
# 8 environmental
# 1 environmentally
# 2 environments
# 1 envision
# 1 epic
# 1 epiccare
# 1 epidemic
# 1 epidemiologists
# 2 epilepsy
# 8 equal
# 4 equality
# 1 equally
# 1 equip
# 26 equipment
# 3 equipped
# 4 equity
# 7 er
# 1 era
# 1 eren
# 4 erie
# 1 eriepa
# 3 erin
# 1 ernie
# 1 errands
# 1 error
# 5 errors
# 1 escalating
# 1 escape
# 2 escort
# 1 escorting
# 1 escorts
# 14 espa
# 9 espanol
# 4 especially
# 2 esq
# 3 essential
# 3 essentials
# 11 essex
# 1 est
# 9 established
# 1 establishment
# 2 estate
# 2 estates
# 1 esteem
# 2 esthetics
# 2 estimate
# 2 estonian
# 1 et
# 1 etc
# 1 ethe
# 1 ethel
# 2 ethical
# 4 ethics
# 1 etta
# 1 eu
# 3 evaluate
# 7 evaluated
# 3 evaluates
# 3 evaluation
# 1 evaluations
# 1 evaluator
# 12 even
# 3 evening
# 17 event
# 140 events
# 1 eventsemergency
# 2 eventually
# 14 ever
# 1 everett
# 45 every
# 1 everybody
# 1 everyday
# 10 everyone
# 7 everything
# 1 everywhere
# 3 evidence
# 3 evident
# 1 evoqcontentlibrary
# 1 evs
# 1 ewing
# 2 exactly
# 1 exam
# 3 example
# 1 examples
# 1 exams
# 4 exceed
# 2 exceeded
# 4 exceeding
# 2 exceeds
# 4 excel
# 1 excelled
# 85 excellence
# 29 excellent
# 1 excelling
# 1 except
# 21 exceptional
# 2 exceptions
# 2 excess
# 1 exchange
# 2 excited
# 3 excitement
# 6 exciting
# 1 exclude
# 1 excludes
# 2 exclusively
# 2 excursions
# 1 executed
# 14 executive
# 1 executives
# 5 exemplary
# 1 exempt
# 6 exercise
# 1 exercises
# 1 exist
# 2 existence
# 2 existing
# 6 expand
# 5 expanded
# 2 expanding
# 6 expansion
# 10 expect
# 1 expectation
# 14 expectations
# 1 expecting
# 1 expense
# 1 expenses
# 76 experience
# 6 experienced
# 5 experiences
# 3 experiencing
# 5 expert
# 9 expertise
# 5 experts
# 13 expires
# 2 explained
# 1 explains
# 6 explore
# 2 exploring
# 1 expos
# 5 express
# 1 expressed
# 1 expressing
# 2 expressway
# 1 ext
# 3 extended
# 1 extending
# 1 extends
# 2 extension
# 2 extensive
# 1 extent
# 4 extra
# 1 extracted
# 2 extraordinary
# 1 extremity
# 10 eye
# 1 eyes
# 1 fa
# 3 face
# 36 facebook
# 1 facet
# 3 facial
# 2 facilisis
# 3 facilitate
# 44 facilities
# 110 facility
# 4 facing
# 6 fact
# 3 factors
# 1 factory
# 8 facts
# 1 faculty
# 1 failing
# 15 failure
# 1 failures
# 4 fair
# 1 fairfax
# 1 fairs
# 8 fairview
# 4 faith
# 1 faiths
# 14 fall
# 2 falling
# 27 falls
# 1 fame
# 2 familiar
# 38 families
# 196 family
# 1 famous
# 1 fancy
# 2 fancybox
# 2 fantastic
# 24 faq
# 38 faqs
# 2 far
# 1 faraon
# 1 fare
# 1 farewell
# 5 farm
# 1 farmer
# 2 farmers
# 1 farmington
# 1 fashion
# 2 fashioned
# 1 fasn
# 2 fast
# 3 fasthealth
# 4 fat
# 3 father
# 1 faucet
# 1 faucets
# 2 favorable
# 1 favorite
# 1 favorites
# 26 fax
# 5 fayette
# 1 fear
# 1 feat
# 2 feature
# 7 featured
# 17 features
# 1 featuring
# 22 february
# 22 federal
# 1 federally
# 7 fee
# 2 feed
# 18 feedback
# 1 feedblitz
# 1 feeding
# 1 feedings
# 19 feel
# 2 feeling
# 1 feelings
# 1 feels
# 1 fees
# 2 feet
# 1 feist
# 1 feite
# 1 felicia
# 4 fellowship
# 1 fellowships
# 1 felt
# 3 female
# 1 fenced
# 3 fennimore
# 1 fenzl
# 3 fertility
# 1 festiv
# 1 festival
# 2 festive
# 4 fetal
# 1 fever
# 2 fewer
# 1 fhp
# 4 fi
# 1 fib
# 1 fiber
# 1 fibrillation
# 3 fidalgo
# 8 field
# 2 fields
# 1 fiesta
# 1 fifteen
# 1 fifth
# 1 figanbaum
# 1 fight
# 1 fighting
# 2 figleaf
# 4 figures
# 1 filed
# 2 filipino
# 4 fill
# 6 filled
# 2 filling
# 1 filmed
# 1 filter
# 1 fin
# 3 final
# 1 finalist
# 3 finally
# 2 finance
# 1 finances
# 84 financial
# 1 financials
# 133 find
# 1 findings
# 4 fine
# 1 finest
# 2 finish
# 1 finished
# 2 finnish
# 2 fire
# 1 fireball
# 3 fireplace
# 1 firewood
# 1 firm
# 1 firms
# 65 first
# 1 fiscal
# 1 fish
# 9 fit
# 35 fitness
# 1 fitquest
# 1 fitter
# 1 fitters
# 1 fitting
# 92 five
# 1 fix
# 5 fl
# 1 fla
# 1 flavor
# 2 flavored
# 1 flexible
# 1 flight
# 12 floor
# 2 floorplans
# 2 floors
# 3 floral
# 2 florence
# 32 florida
# 1 flower
# 3 flowers
# 31 floyd
# 5 flu
# 1 fluffy
# 6 fluid
# 1 fluoroscopy
# 1 flyer
# 1 fmla
# 1 fmr
# 14 focus
# 8 focused
# 1 focuses
# 5 focusing
# 1 folding
# 1 foley
# 21 follow
# 2 followed
# 22 following
# 4 font
# 1 fontaine
# 15 food
# 5 foods
# 13 foot
# 1 football
# 14 footer
# 1 footerbottom
# 3 footercol
# 1 footercol4
# 1 footercontact
# 1 footerlinks
# 1 footersocial
# 1 footgolf
# 1 footsteps
# 8 footworks
# 7 for
# 3 force
# 1 forces
# 2 forcing
# 1 ford
# 2 fore
# 2 forefront
# 1 foreign
# 1 foreman
# 2 foremost
# 1 forensic
# 1 foresight
# 2 forest
# 1 forever
# 4 forget
# 3 forgot
# 4 fork
# 17 form
# 3 format
# 1 formation
# 3 formed
# 4 former
# 4 formerly
# 14 forms
# 5 fort
# 3 forth
# 1 fortunately
# 1 forty
# 2 forum
# 2 forums
# 3 forward
# 4 foster
# 2 fostering
# 8 found
# 96 foundation
# 1 foundational
# 6 founded
# 2 founder
# 2 founders
# 45 four
# 3 fourth
# 12 fox
# 3 foxcare
# 1 foxnow
# 1 fra
# 2 fracture
# 1 fragile
# 1 frailty
# 4 framed
# 1 framework
# 7 fran
# 2 franchise
# 1 francis
# 1 frank
# 2 franklin
# 1 franks
# 1 freas
# 2 fredericka
# 33 free
# 2 freedom
# 1 freely
# 1 freeway
# 2 french
# 9 frene
# 1 frequency
# 1 frequent
# 12 frequently
# 9 fresh
# 1 freshly
# 10 fresno
# 1 fresnosurgicalhospital
# 2 frey
# 17 friday
# 2 fried
# 5 friend
# 1 friendliness
# 14 friendly
# 20 friends
# 3 friendships
# 1 fries
# 1 frist
# 1 frogman
# 2 front
# 2 frosting
# 2 frozen
# 3 fruit
# 1 fruition
# 1 fruits
# 1 fse
# 10 fsh
# 2 ft
# 1 fuel
# 2 fulfill
# 1 fulfillment
# 40 full
# 1 fullwidth
# 11 fully
# 7 fun
# 6 function
# 1 functional
# 5 fund
# 2 fundamental
# 2 funded
# 1 funding
# 5 fundraiser
# 6 fundraising
# 5 funds
# 1 funeral
# 2 furnishings
# 1 furniture
# 1 fusce
# 5 future
# 1 futuremaker
# 2 ga
# 7 gables
# 1 gabriel
# 1 gagana
# 1 gained
# 3 gala
# 2 galician
# 53 gallery
# 1 gallo
# 2 gallup
# 1 galore
# 1 galveston
# 1 gambling
# 1 game
# 1 games
# 2 gamma
# 19 ganey
# 1 gap
# 1 garage
# 9 garden
# 1 gardening
# 14 gardens
# 1 garrett
# 2 gary
# 1 gas
# 16 gastroenterology
# 3 gastrointestinal
# 2 gateway
# 1 gathered
# 1 gathering
# 1 gathers
# 9 gave
# 1 gawonihisdi
# 1 gay
# 1 gayle
# 1 gazebo
# 1 geaux
# 1 gel
# 1 gem
# 3 gender
# 55 general
# 1 generalized
# 2 generation
# 11 generations
# 2 generous
# 1 generously
# 2 genesis
# 3 genetic
# 1 genetics
# 1 genitourinary
# 2 genomic
# 1 gentiva
# 1 gentle
# 4 genuine
# 3 genuinely
# 2 george
# 8 georgia
# 1 georgian
# 1 gerald
# 1 gerard
# 1 gerd
# 11 geriatric
# 4 geriatrician
# 5 geriatrics
# 1 germ
# 3 german
# 1 germs
# 1 gerontologist
# 2 gerontology
# 1 geropsychology
# 54 get
# 10 getting
# 1 gfr
# 1 ghs
# 2 gi
# 1 gibson
# 2 gieseke
# 1 gif
# 91 gift
# 1 giftbags
# 10 gifts
# 1 gila
# 1 gilbert
# 1 gilberttown
# 11 gillette
# 5 ginger
# 1 ginkel
# 1 girl
# 1 girling
# 1 girls
# 45 give
# 2 giveaway
# 13 given
# 1 givers
# 13 gives
# 32 giving
# 14 glacial
# 2 glad
# 1 glands
# 3 glen
# 1 glendale
# 7 glenwood
# 1 glimpse
# 7 global
# 8 glossary
# 25 go
# 17 goal
# 4 goals
# 2 god
# 2 goes
# 9 going
# 13 gold
# 3 golden
# 1 goldfarb
# 7 goleta
# 14 golf
# 1 gonzalez
# 27 good
# 2 goodbye
# 1 goods
# 1 goodwin
# 12 google
# 31 googleoff
# 31 googleon
# 3 got
# 3 gourmet
# 7 gouverneur
# 29 gov
# 2 governed
# 5 governing
# 14 government
# 1 governments
# 1 governor
# 1 gplus
# 20 grace
# 1 gracechirocenter
# 1 graceful
# 4 graciously
# 8 grade
# 3 grades
# 5 graduate
# 6 graduated
# 1 graduating
# 2 graduation
# 1 grain
# 1 grains
# 8 grand
# 1 grandfather
# 1 grandparents
# 1 grandson
# 2 granite
# 1 granlund
# 1 grant
# 2 granted
# 3 grants
# 1 graphics
# 8 grateful
# 1 gratified
# 3 gratitude
# 1 gravity
# 1 grease
# 18 great
# 10 greater
# 1 greatest
# 2 greek
# 13 green
# 1 greene
# 2 greenhealth
# 1 greenhouse
# 1 greens
# 4 greentree
# 3 greenville
# 1 greer
# 1 greeted
# 12 greeting
# 1 greetings
# 1 greg
# 1 gregory
# 1 greiffenhagen
# 3 grew
# 3 grhs
# 1 grief
# 1 grill
# 1 grilled
# 1 grimes
# 1 grinsven
# 2 grmc
# 1 grocery
# 1 grooming
# 1 groovy
# 1 ground
# 1 grounded
# 50 group
# 26 groups
# 12 grove
# 2 grow
# 5 growing
# 4 grown
# 2 growth
# 1 grundy
# 2 gt
# 2 gte
# 1 guacamole
# 1 guam
# 15 guardian
# 11 guest
# 8 guests
# 2 guidance
# 19 guide
# 3 guided
# 9 guidelines
# 1 guidepoint
# 1 guides
# 2 guido
# 1 guild
# 1 guilt
# 1 gull
# 1 gullickson
# 1 gun
# 2 gundersen
# 1 gus
# 3 guymon
# 5 gvch
# 1 gwtg
# 4 gwynedd
# 1 gym
# 5 gyn
# 8 gynecologic
# 2 gynecological
# 1 gynecologists
# 23 gynecology
# 2 habits
# 2 hablamos
# 2 hair
# 2 haitian
# 3 hale
# 8 half
# 1 halifax
# 4 hall
# 2 hallett
# 2 halloween
# 1 halls
# 1 hamilton
# 1 hammocks
# 7 hammond
# 4 hampden
# 5 hampshire
# 1 hampton
# 13 hand
# 1 handbook
# 1 handcrafted
# 1 handful
# 4 handicap
# 2 handle
# 1 handled
# 1 handouts
# 1 handrails
# 8 hands
# 3 handy
# 1 hanes
# 1 hanna
# 3 hanover
# 2 hansel
# 1 hansen
# 1 hanson
# 1 happen
# 1 happening
# 2 happenings
# 5 happens
# 10 happy
# 7 harbor
# 2 harbour
# 4 hard
# 1 harder
# 8 hardin
# 2 hardware
# 3 hardy
# 1 hare
# 1 harm
# 1 harnack
# 7 harold
# 3 harris
# 1 harrison
# 1 hart
# 1 hartford
# 1 hartman
# 1 hartwick
# 2 harvest
# 1 hassie
# 1 hassies
# 1 hat
# 2 hats
# 2 hattiesburg
# 1 haunted
# 1 hauppauge
# 1 haverland
# 4 hawaii
# 1 hawkinson
# 4 hazards
# 42 hcahps
# 2 hcahpsonline
# 3 hcc
# 4 head
# 11 header
# 1 headlamp
# 1 headlines
# 1 headquartered
# 2 headquarters
# 1 heads
# 20 healing
# 820 health
# 223 healthcare
# 2 healthconnection
# 8 healthgrades
# 6 healthier
# 1 healthline
# 2 healthlinks
# 1 healthstream
# 1 healthstrong
# 1 healthsystem
# 1 healthwise
# 4 healthworks
# 56 healthy
# 3 hear
# 2 heard
# 9 hearing
# 98 heart
# 1 heartburn
# 3 heartfelt
# 10 hearthstone
# 1 heartland
# 1 hearts
# 1 heartview
# 2 heartwarming
# 2 heartwood
# 2 heat
# 1 heath
# 1 heating
# 2 heavy
# 2 hebrew
# 1 heen
# 2 hei
# 5 heidi
# 8 heights
# 7 held
# 1 helipad
# 2 hello
# 1 helm
# 93 help
# 6 helped
# 1 helper
# 21 helpful
# 11 helping
# 1 helplessness
# 8 helps
# 1 hematologic
# 6 hematology
# 1 hemo
# 9 hemodialysis
# 1 heneghan
# 1 henkinschultz
# 11 henry
# 1 hepatobiliary
# 4 hepatology
# 1 heptner
# 1 hereby
# 1 hereditary
# 2 heres
# 6 heritage
# 2 herkimer
# 5 hermann
# 1 hero
# 2 heroes
# 1 herron
# 1 hess
# 1 hha
# 1 hhcahps
# 1 hhd
# 4 hhs
# 1 hhu
# 11 hi
# 1 hiatt
# 5 hickory
# 3 hidden
# 1 hide
# 47 high
# 14 higher
# 47 highest
# 1 highlighting
# 5 highlights
# 14 highly
# 1 hightower
# 3 highway
# 1 hill
# 45 hills
# 1 hinckley
# 2 hindi
# 1 hingham
# 1 hinton
# 16 hip
# 5 hipaa
# 2 hiring
# 1 hispanic
# 6 historic
# 1 historicbiltmorevillage
# 59 history
# 1 hitting
# 1 hiv
# 1 hixny
# 3 hmo
# 3 hmoob
# 1 ho
# 1 hobart
# 2 hobbies
# 1 hofman
# 1 holbrook
# 2 hold
# 1 holden
# 1 holding
# 1 holds
# 2 holes
# 2 holiday
# 2 holidays
# 2 holistic
# 1 holland
# 3 holly
# 1 holston
# 572 home
# 2 homebound
# 26 homecare
# 1 homecurrent
# 1 homehealth
# 1 homehealthcompare
# 3 homelike
# 1 homemaker
# 1 homepage
# 40 homes
# 1 homestead
# 3 hometown
# 2 homey
# 1 homilies
# 1 honesty
# 1 honey
# 2 honolulu
# 16 honor
# 6 honored
# 1 honoring
# 9 honors
# 1 hooded
# 1 hoover
# 2 hop
# 11 hope
# 3 hopes
# 1 hopkins
# 3 hopkinsville
# 1 hors
# 2 horton
# 87 hospice
# 703 hospital
# 8 hospitalcompare
# 7 hospitalist
# 1 hospitalists
# 7 hospitality
# 3 hospitalization
# 3 hospitalized
# 1 hospitalqualityinits
# 138 hospitals
# 5 host
# 1 hostettler
# 3 hosting
# 5 hosts
# 1 hot
# 7 hotel
# 3 hotels
# 1 hotline
# 1 hough
# 4 houma
# 11 hour
# 59 hours
# 30 house
# 5 housekeeping
# 1 houses
# 10 housing
# 1 hoverintent
# 2 howard
# 1 howe
# 3 however
# 2 hps
# 2 hqa
# 1 hrc
# 1 href
# 1 hrhc
# 2 hrvatski
# 23 hshs
# 6 html
# 21 http
# 6 https
# 1 hub
# 1 hubbard
# 1 hudrlik
# 1 huffington
# 2 huge
# 2 hughes
# 2 hughston
# 1 huju
# 3 hull
# 21 human
# 1 humanity
# 1 humble
# 1 humidifier
# 1 hundreds
# 2 hungarian
# 2 hungry
# 1 huntington
# 1 huntsville
# 1 hurricane
# 4 husband
# 2 hustle
# 2 hwy
# 1 hydrangea
# 1 hygiene
# 5 hyperbaric
# 4 hypertension
# 1 hyrdocele
# 1 hysterectomy
# 3 ia
# 1 iberia
# 1 icahn
# 1 iccd
# 1 ice
# 2 icelandic
# 1 ich
# 2 icon
# 1 icons
# 4 icu
# 3 id
# 3 idaho
# 1 idea
# 6 ideal
# 1 ideally
# 3 ideas
# 4 identifiable
# 2 identifies
# 6 identify
# 5 identity
# 1 ideology
# 5 ie
# 1 igbo
# 1 ihelp
# 12 ihm
# 1 ihmsisters
# 1 ihrmma
# 3 ii
# 5 iii
# 4 il
# 2 ill
# 11 illinois
# 13 illness
# 3 illnesses
# 1 illustrated
# 1 ilokano
# 2 im
# 1 image
# 1 imager
# 2 images
# 3 imagine
# 53 imaging
# 1 img
# 1 immaculate
# 4 immediate
# 1 immediately
# 1 immersive
# 4 immunization
# 2 immunizations
# 3 immunology
# 1 immunotherapy
# 4 impact
# 1 impacts
# 1 impaired
# 3 impairment
# 1 implant
# 2 implement
# 4 implementation
# 4 implemented
# 2 implementing
# 2 importance
# 22 important
# 1 importantly
# 3 impressive
# 20 improve
# 2 improved
# 19 improvement
# 1 improvements
# 2 improves
# 12 improving
# 38 in
# 1 inappropriate
# 47 inc
# 1 incision
# 34 include
# 7 included
# 24 includes
# 39 including
# 5 inclusion
# 1 inclusive
# 2 income
# 2 incontinence
# 1 inconvenience
# 1 incorporating
# 3 increase
# 1 increased
# 1 increasing
# 2 incredible
# 9 independence
# 35 independent
# 6 independently
# 61 index
# 2 india
# 5 indian
# 8 indiana
# 4 indianapolis
# 1 indians
# 2 indicate
# 2 indicates
# 1 indicating
# 5 indicators
# 1 indigo
# 1 indirect
# 11 individual
# 4 individualized
# 5 individuals
# 2 indonesian
# 2 indoor
# 2 industrial
# 1 industrialized
# 1 industries
# 5 industry
# 4 infant
# 2 infarction
# 19 infection
# 4 infections
# 6 infectious
# 3 infertility
# 1 infirm
# 2 inflatable
# 1 inflation
# 4 influenza
# 38 info
# 174 information
# 1 informational
# 1 informative
# 1 informed
# 2 inforx
# 1 infrastructure
# 1 infrequent
# 13 infusion
# 1 ingredients
# 1 ingrid
# 2 initial
# 1 initializer
# 1 initially
# 2 initiated
# 1 initiation
# 5 initiative
# 5 initiatives
# 1 injected
# 1 injections
# 1 injured
# 5 injuries
# 17 injury
# 1 ink
# 3 inn
# 1 innocents
# 6 innovation
# 6 innovative
# 36 inpatient
# 1 input
# 1 inquiring
# 1 inquiry
# 2 ins
# 3 inside
# 1 insights
# 1 insisted
# 4 inspection
# 8 inspections
# 1 inspectors
# 1 inspiration
# 1 inspire
# 1 inspired
# 2 inspiring
# 3 instagram
# 1 install
# 1 installation
# 2 installed
# 1 instance
# 1 instead
# 1 instilling
# 43 institute
# 1 instituted
# 3 institutes
# 2 institution
# 1 institutional
# 4 institutions
# 2 instruction
# 8 instructions
# 2 instruments
# 1 insty
# 75 insurance
# 1 insurances
# 2 insured
# 1 insurers
# 2 intake
# 1 integracare
# 2 integral
# 3 integrated
# 1 integration
# 1 integrative
# 114 integris
# 2 integrity
# 1 intellectual
# 2 intended
# 15 intensive
# 1 intensivist
# 2 interact
# 2 interaction
# 1 interactions
# 6 interactive
# 1 interchangeable
# 3 interdisciplinary
# 4 interest
# 3 interested
# 1 interesting
# 2 interfere
# 1 intergenerational
# 9 interim
# 1 interior
# 3 intermediate
# 1 intermission
# 5 intermittent
# 28 internal
# 8 international
# 1 internationally
# 6 internet
# 2 internist
# 2 internship
# 4 internships
# 2 interpreter
# 1 interrupt
# 2 interstate
# 1 interstitial
# 1 intertwined
# 8 interventional
# 2 interview
# 1 intranet
# 1 intravenous
# 1 intricately
# 1 introduce
# 1 introduced
# 1 introducing
# 1 invalid
# 3 invasive
# 1 investigating
# 1 investigational
# 2 investigators
# 1 investor
# 1 investors
# 1 invite
# 1 invites
# 4 inviting
# 11 involved
# 9 involvement
# 1 involves
# 7 ios
# 2 iowa
# 1 ip
# 2 ipsum
# 1 iq
# 2 irish
# 1 iron
# 2 ironton
# 1 irvine
# 1 irvington
# 11 island
# 1 islandhospital
# 2 isle
# 1 israelsen
# 1 issue
# 1 issued
# 13 issues
# 1 issuing
# 1 iste
# 2 isu
# 2 italian
# 3 italiano
# 5 itasca
# 5 items
# 1 itri
# 7 iv
# 4 ivantage
# 2 jack
# 1 jackets
# 1 jackson
# 2 jacksonville
# 3 jacob
# 1 jacobs
# 1 jacques
# 10 james
# 1 jamie
# 3 jana
# 3 jane
# 1 janet
# 1 janfreau
# 28 january
# 2 japanese
# 2 jasmine
# 2 java
# 31 javascript
# 1 jay
# 1 jean
# 2 jefferson
# 1 jeffrey
# 1 jeffries
# 1 jennifer
# 3 jensen
# 1 jeny
# 1 jeremy
# 1 jerk
# 2 jerry
# 2 jersey
# 2 jewelers
# 1 jholmvig
# 10 jill
# 6 jim
# 1 jimmy
# 3 jkve
# 4 jmh
# 26 job
# 23 jobs
# 1 joel
# 1 jogging
# 6 john
# 1 johns
# 9 johnson
# 1 johnsville
# 20 join
# 8 joined
# 6 joining
# 2 joins
# 84 joint
# 1 jointcommission
# 1 jones
# 3 jonette
# 3 jordan
# 3 jose
# 32 joseph
# 1 joslin
# 3 journal
# 9 journey
# 10 joy
# 14 jquery
# 1 jr
# 38 js
# 1 jstewart
# 1 jubilarians
# 1 jubilee
# 1 juice
# 1 jul
# 1 julia
# 1 julie
# 38 july
# 1 jump
# 1 jumping
# 1 jun
# 48 june
# 1 juneau
# 7 junior
# 3 justice
# 1 justin
# 1 justly
# 1 kajin
# 3 kalbacka
# 1 kan
# 1 kane
# 1 kaneohe
# 1 kankakee
# 3 kansas
# 3 kaplan
# 1 kappa
# 1 karels
# 1 karen
# 1 karestan
# 1 kartik
# 2 kassahn
# 4 kassem
# 1 kathi
# 1 kathy
# 7 katy
# 2 kauai
# 1 kay
# 1 kayakers
# 2 kcpcc
# 1 kee
# 9 keep
# 8 keeping
# 3 keeps
# 1 keepsafe
# 5 kelly
# 4 ken
# 1 kendall
# 2 kennedy
# 21 kentucky
# 1 kept
# 1 kerrebroeck
# 1 ketchup
# 1 kevyn
# 14 key
# 1 keyhie
# 1 keys
# 5 kiahtipes
# 1 kid
# 32 kidney
# 1 kidneys
# 7 kids
# 2 kim
# 8 kind
# 1 kindergarten
# 2 kindest
# 3 kindness
# 9 kindred
# 2 kinds
# 1 kingsley
# 1 kingston
# 1 kirk
# 1 kissimmee
# 1 kiswahili
# 7 kitchen
# 1 kitchens
# 1 kits
# 10 knee
# 4 knew
# 22 know
# 10 knowing
# 3 knowledge
# 12 known
# 3 knox
# 3 koochiching
# 2 koop
# 2 korean
# 1 kortright
# 3 kosair
# 1 kresowik
# 2 krey
# 1 kris
# 1 krissy
# 2 kristi
# 1 kristie
# 1 kristin
# 1 kristine
# 1 ks
# 1 kudos
# 1 kuecker
# 3 kuhn
# 3 kupuna
# 7 ky
# 12 la
# 15 lab
# 1 labatisse
# 4 labor
# 3 laboratories
# 59 laboratory
# 3 laborde
# 2 lacs
# 2 lactation
# 2 lacus
# 1 laden
# 1 ladies
# 1 lagrange
# 1 lagrima
# 3 lake
# 2 lakeland
# 5 lakes
# 9 lakeside
# 1 lakeview
# 4 lamar
# 1 lamb
# 1 lambert
# 1 lana
# 2 lancaster
# 3 land
# 2 landscape
# 1 landscapes
# 1 lane
# 6 laney
# 1 lang
# 1 langford
# 17 language
# 2 lanham
# 1 lanyard
# 1 laoreet
# 1 laparoscopic
# 1 laptop
# 1 lara
# 10 large
# 5 larger
# 4 largest
# 3 larry
# 2 las
# 1 lasalle
# 1 lasik
# 20 last
# 1 lasts
# 1 late
# 1 lately
# 5 later
# 18 latest
# 2 latvian
# 1 lauer
# 1 launch
# 1 launched
# 1 launches
# 4 laundry
# 1 laura
# 1 laurel
# 4 laurels
# 1 laurens
# 1 laurie
# 9 law
# 4 lawrence
# 2 laws
# 1 lawson
# 1 lay
# 2 layout
# 1 lcca
# 3 le
# 1 lead
# 17 leader
# 2 leaders
# 53 leadership
# 9 leading
# 1 leads
# 1 league
# 2 lean
# 11 leapfrog
# 96 learn
# 3 learned
# 6 learning
# 5 least
# 4 leave
# 1 leaving
# 1 lecture
# 1 lectured
# 7 led
# 1 ledoux
# 6 lee
# 3 leeann
# 3 leed
# 4 left
# 10 legacy
# 6 legal
# 1 legion
# 2 legislators
# 1 legs
# 2 lehi
# 2 leisure
# 2 length
# 1 lennox
# 3 leo
# 1 leonard
# 1 lesbian
# 1 leslie
# 5 less
# 1 lessen
# 1 lessons
# 6 let
# 6 letter
# 1 letters
# 1 leukemia
# 32 level
# 10 levels
# 1 levi
# 3 lgbt
# 2 lgbtq
# 3 lha
# 1 li
# 1 liability
# 1 liaisons
# 3 libertas
# 3 liberty
# 1 librarian
# 1 librarians
# 6 libraries
# 31 library
# 1 libs
# 5 license
# 29 licensed
# 1 licenses
# 1 licensing
# 1 licensure
# 112 life
# 16 lifecare
# 7 lifeline
# 2 lifelong
# 9 lifestream
# 1 lifestreamliving
# 23 lifestyle
# 2 lifetime
# 1 lifeworks
# 9 light
# 1 lighted
# 3 lighting
# 1 lights
# 1 ligula
# 2 lihue
# 46 like
# 2 likelihood
# 1 likewise
# 2 liliha
# 1 lilly
# 2 lime
# 1 limestone
# 1 limit
# 9 limited
# 2 limiting
# 14 lincoln
# 1 lincolnwood
# 4 linda
# 3 line
# 1 lined
# 1 linens
# 29 link
# 2 linked
# 8 linkedin
# 1 linking
# 46 links
# 1 linnette
# 1 liquors
# 1 lisbon
# 26 list
# 3 listed
# 2 listen
# 1 listened
# 1 listening
# 6 listing
# 3 listings
# 1 lists
# 1 lite
# 1 literally
# 2 lithuanian
# 24 little
# 1 liturgical
# 22 live
# 1 lived
# 2 liver
# 16 lives
# 146 living
# 1 livingston
# 11 llc
# 3 llena
# 1 llp
# 2 lnha
# 2 loading
# 1 loan
# 3 lobby
# 1 lobectomy
# 31 local
# 7 locally
# 2 locate
# 23 located
# 37 location
# 95 locations
# 2 locator
# 1 locked
# 14 lodge
# 5 lodging
# 4 log
# 1 logan
# 1 logansport
# 1 logging
# 27 login
# 1 logingroup
# 1 logistics
# 8 logo
# 1 london
# 1 loneliness
# 63 long
# 2 longer
# 1 longterm
# 2 longville
# 11 look
# 1 looked
# 22 looking
# 1 looks
# 1 lookup
# 1 loomed
# 2 lopez
# 2 lorain
# 2 lorem
# 2 lori
# 1 lorraine
# 2 los
# 1 lose
# 1 losing
# 22 loss
# 2 lost
# 9 lot
# 1 lots
# 1 loud
# 2 louis
# 23 louisiana
# 2 louisville
# 2 lounge
# 1 lounges
# 19 love
# 17 loved
# 3 lovely
# 2 loving
# 2 low
# 3 lowe
# 2 lower
# 3 lowest
# 1 loyalty
# 2 lpn
# 1 lrg
# 3 lsh
# 3 lsvt
# 1 lt
# 3 ltc
# 1 ltcrevolution
# 2 ltd
# 1 lubbock
# 1 lube
# 1 lumber
# 8 lunch
# 1 lundrigan
# 4 lung
# 1 lungs
# 1 lurtheran
# 2 lutcher
# 1 lutheran
# 1 luxurious
# 1 luxury
# 2 lvn
# 1 lyman
# 4 lymphedema
# 1 lymphoscintigraphy
# 1 lynchburg
# 1 lynn
# 1 maavgnationalavgpatient
# 1 mabraham
# 2 macedonian
# 2 machines
# 1 macomber
# 15 made
# 2 madera
# 4 madison
# 13 magazine
# 2 magazines
# 3 magnet
# 3 magnetic
# 1 magnificent
# 1 mahadevia
# 6 mail
# 2 mailing
# 34 main
# 6 maine
# 1 mainly
# 11 maintain
# 3 maintained
# 2 maintaining
# 3 maintains
# 2 maintenance
# 1 maitland
# 1 majestic
# 9 major
# 2 majority
# 5 makaha
# 74 make
# 1 maker
# 1 makers
# 6 makes
# 19 making
# 2 malay
# 2 male
# 3 malea
# 1 mall
# 2 maltese
# 2 mama
# 1 mammogram
# 3 mammograms
# 16 mammography
# 1 man
# 3 manage
# 1 manageable
# 6 managed
# 104 management
# 6 manager
# 1 managers
# 3 managing
# 1 manazir
# 1 manchester
# 1 manderson
# 1 manganese
# 2 mango
# 1 manicures
# 1 manifest
# 4 manner
# 1 mannered
# 26 manor
# 1 mansfield
# 1 mantianed
# 2 manual
# 30 many
# 74 map
# 16 maps
# 1 mararitaville
# 1 marcell
# 27 march
# 1 marco
# 1 marcus
# 1 margaritavile
# 7 margaritaville
# 1 margin
# 14 maria
# 1 marian
# 2 mariann
# 5 marie
# 1 marilyn
# 7 marion
# 1 marital
# 5 mark
# 16 market
# 21 marketing
# 9 marketplace
# 1 markets
# 1 markman
# 1 marks
# 1 marksville
# 1 markup
# 1 marlborough
# 1 married
# 3 marrow
# 4 mars
# 1 marsha
# 3 marshall
# 1 marshfield
# 1 marthaler
# 1 marveline
# 1 marx
# 9 mary
# 1 marygrove
# 7 maryland
# 2 marysville
# 12 mason
# 1 mass
# 8 massachusetts
# 8 massage
# 1 massop
# 3 mastectomy
# 5 master
# 2 masters
# 1 masthead
# 1 matching
# 1 mater
# 3 materials
# 7 maternal
# 13 maternity
# 1 maters
# 1 matt
# 4 matter
# 10 matters
# 1 maumee
# 1 maurie
# 1 mauris
# 1 mauston
# 1 max
# 4 maxillofacial
# 2 maximize
# 1 maximizing
# 3 maximum
# 1 maxis
# 1 maxiumum
# 87 may
# 1 mayecreate
# 3 mayfair
# 36 mayo
# 2 mayor
# 1 mazomanie
# 1 mccallum
# 1 mccann
# 1 mccaw
# 1 mcconnell
# 1 mch
# 1 mckinney
# 1 mclarney
# 21 md
# 3 mds
# 29 meadows
# 1 meadville
# 12 meal
# 21 meals
# 2 mean
# 5 meaningful
# 6 means
# 1 meant
# 15 measure
# 4 measured
# 1 measurement
# 3 measurements
# 1 measurer
# 53 measures
# 1 measuring
# 1 mechanical
# 1 mecklenburg
# 6 med
# 1 medchecks
# 1 medexpress
# 20 media
# 1 median
# 66 medicaid
# 381 medical
# 6 medically
# 142 medicare
# 18 medication
# 5 medications
# 206 medicine
# 2 medicines
# 1 medspa
# 36 meet
# 18 meeting
# 12 meetings
# 8 meets
# 4 meghan
# 1 melanie
# 4 melanoma
# 1 melbourne
# 28 member
# 40 members
# 11 membership
# 1 memberships
# 1 memorabilia
# 1 memorable
# 50 memorial
# 1 memoriam
# 3 memories
# 53 memory
# 14 men
# 1 mendes
# 1 menk
# 14 mental
# 1 mentally
# 2 mention
# 1 mentioned
# 1 mentored
# 1 mentoring
# 68 menu
# 1 mercury
# 1 meridian
# 1 merit
# 2 merited
# 1 merle
# 4 merrill
# 4 merry
# 3 mesmerize
# 5 mesquite
# 7 message
# 1 messimer
# 7 met
# 1 metabolic
# 1 metabolism
# 1 metal
# 1 metalworks
# 1 method
# 2 methodist
# 1 methods
# 1 metric
# 4 metrics
# 13 metro
# 2 metrogr
# 1 metrohealth
# 1 metropolitan
# 3 mexico
# 2 meyer
# 7 mgh
# 1 mgr
# 1 mhs
# 9 mi
# 11 miami
# 1 mich
# 38 michael
# 3 michigan
# 2 mickey
# 1 mickiewicz
# 1 microsurgery
# 1 microwave
# 1 microwaves
# 3 mid
# 2 middle
# 2 middleburgh
# 1 middletown
# 4 midtown
# 6 midwest
# 1 midwestern
# 1 midwife
# 2 might
# 5 mike
# 1 mikeal
# 9 mile
# 3 miles
# 1 milestones
# 1 milford
# 3 milk
# 2 mille
# 13 miller
# 1 millie
# 3 million
# 1 milton
# 1 milwaukee
# 2 mimis
# 2 min
# 8 mind
# 1 minded
# 2 minds
# 3 mini
# 1 minimal
# 2 minimally
# 3 minimum
# 2 minister
# 6 ministries
# 1 ministry
# 2 minneapolis
# 15 minnesota
# 3 minor
# 1 mint
# 1 minute
# 9 minutes
# 3 miracle
# 1 missed
# 110 mission
# 2 missionhospitals
# 1 missions
# 6 mississippi
# 14 missouri
# 1 mitchell
# 1 mm
# 9 mn
# 7 mo
# 1 moa
# 5 mobile
# 3 mobilemenu
# 1 mobilephone
# 1 mobilesearch
# 3 mobility
# 2 modalities
# 2 modalpopup
# 11 model
# 3 modern
# 1 modernization
# 1 modernizr
# 2 modify
# 1 module
# 1 mohamad
# 2 moi
# 1 mom
# 2 moment
# 1 momentum
# 1 momi
# 1 moms
# 1 mon
# 16 monday
# 1 mondovi
# 2 money
# 1 monitor
# 4 monitoring
# 1 monitors
# 4 monroe
# 1 montana
# 3 monte
# 1 montefiore
# 2 montessori
# 25 month
# 9 monthly
# 3 months
# 3 mood
# 2 moonlite
# 1 moore
# 1 mooresville
# 1 moose
# 1 morbi
# 1 morbidity
# 3 morey
# 2 morgan
# 4 morris
# 1 mortality
# 8 mosaic
# 7 mother
# 2 motherhouse
# 1 mothers
# 2 motors
# 1 motto
# 1 moulton
# 1 mound
# 5 mount
# 7 mountain
# 1 mountains
# 10 move
# 6 moved
# 3 movement
# 4 moves
# 1 movies
# 5 moving
# 2 mph
# 2 mr
# 10 mri
# 5 ms
# 1 msc
# 4 msn
# 1 msp
# 4 mt
# 13 much
# 1 mullin
# 2 multi
# 1 multicultural
# 1 multidisciplinary
# 1 multimedia
# 4 multiple
# 1 multitude
# 2 muncie
# 2 municipal
# 1 municipally
# 1 munshi
# 1 muransky
# 3 murfreesboro
# 7 muscle
# 1 muscular
# 1 museum
# 1 museums
# 5 music
# 1 musical
# 17 must
# 1 mustache
# 2 mustang
# 1 mutual
# 2 mycare
# 2 mycarolinas
# 1 myceo
# 10 mychart
# 1 mycigna
# 1 myctca
# 3 mydavita
# 1 mydch
# 6 myers
# 1 myerson
# 1 myfuture
# 1 myhealth
# 1 myhealthplan
# 2 myhealthy
# 1 myislandhealth
# 1 myjob
# 1 mylife
# 1 mymetro
# 1 mymlc
# 1 mymosaic
# 1 mynhchomecare
# 2 myocardial
# 1 myohh
# 2 myrecord
# 1 myteam
# 1 mytools
# 1 myvirginiamason
# 1 nacc
# 1 naiis
# 28 name
# 36 named
# 3 names
# 3 nancy
# 1 nanette
# 1 nannp
# 1 nap
# 2 naples
# 4 nashville
# 1 nassau
# 1 natalie
# 22 nation
# 94 national
# 9 nationally
# 16 nationwide
# 2 natural
# 2 nature
# 1 natus
# 5 nav
# 2 naval
# 3 navigate
# 24 navigation
# 1 navigators
# 2 nazih
# 2 nbc
# 14 nc
# 1 ncarboretum
# 1 nccc
# 1 ncdr
# 1 ncnatural
# 1 ncparks
# 3 ncqa
# 1 ncs
# 1 ncusfs
# 8 nd
# 6 ne
# 6 near
# 1 nearby
# 3 nearly
# 1 neat
# 16 nebraska
# 1 necedah
# 1 necessarily
# 5 necessary
# 13 neck
# 1 necklace
# 2 nederlands
# 1 nee
# 60 need
# 15 needed
# 71 needs
# 1 needsprivacy
# 1 negative
# 1 negotiating
# 7 neighborhood
# 1 neighborhoods
# 1 neighboring
# 1 neighbors
# 2 neil
# 5 nejat
# 1 nellie
# 4 nelson
# 7 neonatal
# 1 neonatology
# 5 nephrologist
# 1 nephrologists
# 17 nephrology
# 1 nervous
# 1 nesquick
# 1 nest
# 1 nestled
# 2 net
# 1 netlearning
# 1 netsp
# 1 netted
# 28 network
# 5 networks
# 1 networksolutions
# 3 neuro
# 3 neurodiagnostics
# 1 neurologic
# 9 neurological
# 26 neurology
# 3 neuromuscular
# 1 neuropathology
# 1 neurophysiological
# 1 neurophysiology
# 3 neuropsychology
# 3 neuroradiology
# 2 neuroscience
# 2 neurosciences
# 1 neurosurgeons
# 8 neurosurgery
# 2 neurotology
# 1 nevada
# 8 never
# 107 new
# 3 newborn
# 2 newborns
# 1 newcomb
# 1 newer
# 1 newest
# 1 newly
# 1 newnan
# 1 newport
# 208 news
# 19 newsletter
# 21 newsletters
# 12 newsroom
# 1 newswith
# 2 newtown
# 8 next
# 2 nextgen
# 1 nf
# 7 ng
# 1 nh
# 2 nha
# 8 nhc
# 1 nhchomecaredickson
# 1 nhcompare
# 1 nhsc
# 2 niccole
# 3 nice
# 1 nicer
# 1 niche
# 2 nicholas
# 1 nickel
# 1 nickelodeon
# 4 nicole
# 1 nicu
# 5 nifong
# 10 night
# 1 nights
# 4 nikki
# 1 niles
# 8 nine
# 2 ninth
# 1 nj
# 2 nm
# 1 nnp
# 1 nocturnal
# 1 nodaway
# 1 noh
# 1 noindex
# 27 non
# 23 nondiscrimination
# 2 none
# 3 nonprofit
# 1 nonprofits
# 1 noon
# 1 noozhawk
# 1 nor
# 2 nora
# 4 norfolk
# 3 normal
# 1 normally
# 2 norman
# 2 norske
# 30 north
# 3 northeast
# 13 northern
# 2 northfield
# 1 northport
# 19 northside
# 1 northwest
# 1 northwestern
# 2 norwegian
# 4 norwell
# 1 norwich
# 8 nose
# 7 not
# 1 notable
# 3 note
# 1 notes
# 45 notice
# 1 noticed
# 2 notices
# 2 notification
# 1 notify
# 1 notion
# 1 notorious
# 1 nourishing
# 13 nov
# 1 nova
# 1 novarad
# 37 november
# 1 nowell
# 1 np
# 2 nsqip
# 14 nuclear
# 2 nulla
# 20 number
# 9 numbers
# 7 numerous
# 1 nunneley
# 67 nurse
# 13 nursery
# 43 nurses
# 259 nursing
# 2 nursinghomecompare
# 1 nursinghomes
# 1 nurtures
# 2 nurturing
# 30 nutrition
# 9 nutritional
# 1 nutritionally
# 1 nutritionists
# 4 nutritious
# 1 nv
# 9 nvna
# 1 nw
# 9 ny
# 1 nyc
# 1 oahu
# 14 oak
# 1 oakbrook
# ...
# 3 roll
# 1 rollout
# 2 rom
# 2 romanian
# 1 rona
# 1 roof
# 1 roofing
# 47 room
# 25 rooms
# 3 rose
# 1 roses
# 1 ross
# 1 rotary
# 1 rotation
# 1 rouge
# 4 round
# 1 rounds
# 3 routinely
# 15 row
# 3 roxbury
# 2 rph
# 1 rsm
# 3 rss
# 1 rt
# 1 rudy
# 1 rueters
# 1 rug
# 10 run
# 2 runners
# 4 running
# 20 rural
# 66 rush
# 1 rushville
# 1 russell
# 1 russellville
# 1 russelville
# 2 russian
# 1 rustic
# 1 rustica
# 1 ruttger
# 1 rv
# 1 rw
# 8 rwc
# 2 rx
# 3 ryan
# 1 sabbatical
# 1 sac
# 9 sacred
# 21 safe
# 1 safeguards
# 4 safely
# 1 safest
# 68 safety
# 1 safford
# 1 sage
# 1 sagittis
# 17 said
# 3 saindon
# 1 saint
# 2 saints
# 3 salad
# 1 salads
# 1 sale
# 1 sales
# 1 sally
# 1 salon
# 2 saloon
# 1 salsa
# 1 sample
# 3 san
# 1 sandstone
# 1 sandwich
# 1 sandwiches
# 7 sandy
# 2 sanford
# 1 sanjiv
# 3 sanslow
# 27 santa
# 1 sarah
# 6 sarasota
# 1 sarcomas
# 1 sasha
# 2 satellite
# 53 satisfaction
# 1 satkauskas
# 7 saturday
# 1 saturdays
# 1 sauce
# 1 saucee
# 1 sauces
# 34 sauk
# 1 savannah
# 2 save
# 1 saved
# 1 saves
# 2 saving
# 1 sawmill
# 8 say
# 11 says
# 1 sb
# 6 sbch
# 1 sbcp
# 4 sc
# 8 scale
# 7 scan
# 2 scanner
# 1 scanning
# 3 scans
# 1 scary
# 2 scenic
# 1 scent
# 19 schedule
# 5 scheduled
# 1 schedules
# 6 scheduling
# 4 scheels
# 1 schenevus
# 1 scheppers
# 1 schmach
# 1 schoharie
# 6 scholarship
# 8 scholarships
# 36 school
# 1 schools
# 1 schowengerdt
# 1 schramm
# 1 schreiner
# 2 schrock
# 3 schroeder
# 12 science
# 5 sciences
# 1 scientific
# 1 scientist
# 1 scip
# 1 scituate
# 1 sclerosis
# 2 scope
# 11 score
# 4 scorecard
# 19 scores
# 2 scoring
# 1 scorning
# 3 scorpion
# 4 scott
# 2 screen
# 3 screening
# 13 screenings
# 1 screwdrivers
# 5 script
# 1 scripting
# 1 scripts
# 2 scroll
# 1 scrub
# 7 sd
# 4 se
# 3 sea
# 2 seafood
# 4 seal
# 1 seamar
# 88 search
# 2 searched
# 1 searching
# 4 searchskinobjectpreview
# 3 season
# 2 seasonal
# 2 seasoned
# 1 seasonings
# 1 seasons
# 2 seat
# 2 seattle
# 1 sebring
# 9 second
# 4 secondary
# 3 seconds
# 14 secours
# 1 secret
# 4 secretary
# 2 secrets
# 9 section
# 1 sectionid
# 1 sections
# 1 sector
# 6 secure
# 1 secured
# 1 securemail
# 3 security
# 4 sed
# 1 sedation
# 32 see
# 1 seeds
# 2 seek
# 4 seeking
# 1 seeks
# 1 seemed
# 2 seems
# 1 seen
# 17 select
# 12 selected
# 2 selecting
# 1 selection
# 1 selections
# 9 self
# 1 selling
# 1 selma
# 1 semester
# 4 semi
# 3 seminar
# 4 seminars
# 1 seminary
# 1 semiprivate
# 29 send
# 45 senior
# 4 seniorcare
# 9 seniors
# 4 sense
# 1 senses
# 4 sensitive
# 2 sensitivity
# 2 sensory
# 2 sent
# 2 seo
# 4 sep
# 2 separate
# 1 separately
# 2 sepsis
# 40 september
# 2 serbian
# 1 serenity
# 8 series
# 3 seriously
# 1 servants
# 19 serve
# 10 served
# 9 serves
# 87 service
# 1 serviced
# 786 services
# 2 servicesframework
# 1 servicesphysical
# 14 serving
# 2 session
# 3 sessions
# 13 set
# 1 sets
# 17 setting
# 6 settings
# 1 settling
# 4 setup
# 14 seven
# 3 seventh
# 10 several
# 3 severe
# 1 severely
# 1 sevices
# 4 sex
# 1 sexton
# 1 sexual
# 1 seymour
# 1 sfsh
# 2 shadi
# 3 shadow
# 2 shadowing
# 1 shaped
# 37 share
# 8 shared
# 10 shares
# 2 sharing
# 1 sharon
# 1 sharp
# 1 sharris
# 2 shave
# 1 sheila
# 1 shelter
# 1 shephard
# 2 sherburne
# 4 sherman
# 4 shield
# 2 shields
# 1 shift
# 1 shilkoff
# 1 shindig
# 1 shine
# 1 shined
# 2 shineon
# 1 shipping
# 3 shirley
# 1 shirt
# 3 shirts
# 1 shoals
# 2 shoe
# 1 shooters
# 1 shooting
# 39 shop
# 5 shoppe
# 3 shopping
# 2 shops
# 1 shore
# 1 shoreline
# 34 short
# 1 shortens
# 2 shortly
# 1 shots
# 4 shoulder
# 1 shouldering
# 7 show
# 1 showed
# 1 shower
# 1 showering
# 1 showers
# 3 showing
# 3 shown
# 6 shows
# 1 shqip
# 2 shrimp
# 3 shumway
# 2 shutter
# 1 shuttle
# 1 sibling
# 1 sicilian
# 2 sick
# 1 sickness
# 6 side
# 1 sidekickcreative
# 4 sidney
# 1 sids
# 1 sightseers
# 1 sigma
# 32 sign
# 1 signage
# 1 signal
# 5 signature
# 2 significant
# 4 significantly
# 7 signs
# 3 signup
# 1 signworks
# 4 silent
# 1 silkier
# 1 silver
# 1 silverchair
# 1 silverman
# 1 similar
# 3 simple
# 1 simplified
# 7 simply
# 1 simulated
# 2 sinai
# 35 since
# 2 single
# 1 singlenest
# 2 sink
# 6 sioux
# 3 sip
# 1 siraj
# 5 sister
# 10 sisters
# 4 sit
# 88 site
# 16 sitemap
# 8 sites
# 1 siteseal
# 1 sitewrapper
# 1 sits
# 1 sitting
# 2 situated
# 1 situation
# 3 sity
# 10 six
# 3 sixth
# 10 size
# 3 sized
# 3 sizes
# 3 sjph
# 1 skaalure
# 3 skagit
# 1 skewers
# 1 skill
# 89 skilled
# 5 skills
# 7 skin
# 19 skins
# 17 skip
# 2 skowhegan
# 1 skyadmin
# 1 skype
# 1 slatter
# 53 sleep
# 1 sleeve
# 1 slice
# 4 slider
# 1 sliders
# 1 slideshow
# 3 sliding
# 1 sling
# 2 slovak
# 2 slovenian
# 2 sm
# 5 small
# 5 smaller
# 6 smart
# 7 smh
# 1 smile
# 1 smiled
# 2 smith
# 1 smithville
# 1 smock
# 2 smoke
# 1 smokey
# 6 smoking
# 1 smoothies
# 8 snacks
# 2 snapshot
# 2 sneak
# 1 snider
# 1 snowmass
# 1 snyder
# 1 soak
# 1 sociability
# 48 social
# 1 socialization
# 3 socially
# 1 socials
# 20 society
# 1 socioeconomic
# 1 socks
# 2 soda
# 1 soft
# 2 software
# 1 softwareone
# 6 soiree
# 1 solar
# 4 solaris
# 2 solarisfoundation
# 1 sold
# 1 sole
# 2 solid
# 1 sollicitudin
# 1 solution
# 3 solutions
# 1 solvang
# 14 someone
# 5 somerset
# 9 something
# 2 sometimes
# 3 son
# 2 sons
# 5 soon
# 1 sooner
# 4 soothing
# 1 sophisticated
# 1 soria
# 1 sothers
# 1 sought
# 1 soul
# 2 sound
# 1 soup
# 1 soups
# 3 source
# 1 sources
# 28 south
# 2 southeastern
# 6 southern
# 1 southport
# 3 southside
# 14 southwest
# 1 southwestern
# 18 southwoods
# 1 southwoodshealth
# 1 sowder
# 1 sox
# 7 spa
# 3 space
# 4 spaces
# 8 spacious
# 1 spalding
# 1 spam
# 1 spambots
# 9 span
# 9 spanish
# 1 spares
# 1 sparked
# 1 sparkling
# 5 speak
# 3 speaker
# 1 speakers
# 6 speaking
# 1 spearheaded
# 36 special
# 5 specialist
# 22 specialists
# 1 specialities
# 3 specialize
# 7 specialized
# 4 specializes
# 1 specializing
# 2 specially
# 1 specials
# 20 specialties
# 52 specialty
# 12 specific
# 5 specifically
# 1 specify
# 1 specimens
# 3 spectrum
# 27 speech
# 6 spend
# 1 spending
# 2 spends
# 4 spent
# 5 sph
# 1 spicy
# 1 spill
# 14 spine
# 1 spinecare
# 5 spirit
# 17 spiritual
# 6 spirituality
# 1 spiritually
# 1 splash
# 1 spokane
# 1 spokespersons
# 6 sponsored
# 4 sponsors
# 5 sponsorship
# 37 sports
# 2 sportscare
# 1 sportsmedicine
# 1 spot
# 9 spotlight
# 4 spotlights
# 1 spouse
# 1 spouses
# 1 spray
# 1 spreading
# 17 spring
# 1 springer
# 1 springfield
# 4 springs
# 3 sprinkler
# 1 sprinklers
# 10 square
# 1 squarespace
# 1 sr
# 1 srhs
# 2 srpsko
# 1 ssi
# 99 st
# 2 stability
# 1 stable
# 1 stacie
# 1 stacks
# 152 staff
# 3 staffed
# 19 staffing
# 6 stage
# 1 stagekidney
# 5 stages
# 1 stakeholder
# 2 stamato
# 3 stamford
# 1 stance
# 2 stand
# 10 standard
# 10 standardized
# 30 standards
# 1 standing
# 2 stands
# 1 stanford
# 156 star
# 1 starkville
# 43 stars
# 15 start
# 13 started
# 4 starting
# 2 starts
# 94 state
# 1 stated
# 29 statement
# 1 statementcharity
# 21 states
# 1 static
# 1 station
# 1 stations
# 3 statistics
# 9 status
# 1 statute
# 1 statutes
# 51 stay
# 2 stayed
# 4 staying
# 2 stays
# 1 steak
# 1 stefani
# 2 stensrud
# 3 step
# 1 stephens
# 1 steps
# 2 stereotactic
# 1 sterile
# 3 steven
# 4 stewart
# 1 stews
# 1 stifled
# 9 still
# 1 stimulate
# 4 stimulating
# 4 stimulation
# 1 stimuli
# 1 stinson
# 1 stint
# 2 stna
# 1 stocktrail
# 1 stokes
# 9 stonebridge
# 1 stonecrest
# 2 stones
# 2 stop
# 1 stops
# 2 storage
# 8 store
# 23 stories
# 13 story
# 1 strabismus
# 4 straight
# 1 strategic
# 1 strategically
# 2 strategies
# 36 street
# 5 strength
# 1 strengthen
# 1 strengthens
# 1 strengths
# 5 stress
# 3 stressful
# 1 strict
# 2 stride
# 1 stringent
# 21 strive
# 2 strives
# 1 striving
# 48 stroke
# 1 stroll
# 2 strom
# 6 strong
# 1 stronger
# 1 strongly
# 1 struchtemeyer
# 2 structure
# 2 structured
# 1 struggle
# 1 struggling
# 1 stryker
# 3 stubbs
# 3 student
# 3 students
# 9 studer
# 4 studies
# 3 studio
# 9 study
# 1 studying
# 2 stumbleupon
# 9 style
# 2 stylesheets
# 1 subject
# 2 submission
# 11 submit
# 2 submitted
# 1 subpage
# 3 subs
# 5 subscribe
# 3 subscription
# 1 subsequent
# 1 subset
# 1 subsidiary
# 1 substances
# 1 substantial
# 2 substitute
# 2 suburban
# 1 succeed
# 13 success
# 1 successes
# 7 successful
# 2 successfully
# 1 sudden
# 2 sue
# 1 suffer
# 7 suffering
# 1 sufficiency
# 2 suffolk
# 3 sugar
# 2 suggested
# 1 suggestion
# 3 suggestions
# 1 suggests
# 1 suicide
# 15 suite
# 1 suited
# 14 suites
# 2 sullivan
# 1 summa
# 1 summarize
# 1 summarizes
# 11 summary
# 24 summer
# 1 summit
# 8 sun
# 6 sunday
# 3 sunny
# 1 sunrise
# 1 sunscreen
# 2 sunset
# 1 super
# 5 superior
# 1 supervised
# 5 supervision
# 1 supervisor
# 1 supervisors
# 1 supper
# 4 supplies
# 5 supply
# 91 support
# 3 supported
# 1 supporters
# 7 supporting
# 7 supportive
# 1 supports
# 1 supraventricular
# 8 sure
# 5 surgeon
# 18 surgeons
# 7 surgeries
# 225 surgery
# 109 surgical
# 1 surpassed
# 1 surprise
# 2 surprises
# 1 surprisingly
# 1 surrey
# 2 surround
# 1 surrounded
# 5 surrounding
# 2 surroundings
# 57 survey
# 1 surveyed
# 10 surveys
# 3 survivors
# 2 survivorship
# 4 susan
# 1 suspended
# 1 susquehanna
# 2 sustain
# 3 sustainability
# 2 sustainable
# 1 sustained
# 1 sustains
# 1 suture
# 1 suzanne
# 2 sw
# 2 swahili
# 1 swallowing
# 2 sweatshirt
# 2 swedish
# 3 sweet
# 2 sweeten
# 1 sweets
# 1 swelling
# 1 swimming
# 4 swing
# 1 swtc
# 1 sydell
# 1 sylacauga
# 3 symbol
# 5 symptoms
# 1 syncope
# 3 syndrome
# 1 synergy
# 1 syracuse
# 96 system
# 20 systems
# 1 tab
# 1 tabata
# 3 table
# 1 tablet
# 1 tachycardia
# 1 tacoma
# 5 tag
# 6 tagalog
# 1 tagged
# 1 tagline
# 5 tags
# 2 tailored
# 32 take
# 4 taken
# 6 takes
# 10 taking
# 3 talent
# 1 talented
# 3 taleo
# 1 tales
# 2 talk
# 1 talking
# 2 talks
# 1 tamarack
# 2 tammy
# 2 tampa
# 1 tanks
# 1 tannerite
# 1 tap
# 1 target
# 2 tari
# 1 task
# 1 tasked
# 1 tasks
# 2 tasting
# 3 tatton
# 1 tau
# 2 tawk
# 1 tawnaya
# 2 tax
# 1 taxing
# 1 taylorville
# 1 tbh
# 4 tbhc
# 2 tcc
# 1 tcc4care
# 2 tea
# 2 teach
# 1 teaches
# 2 teaching
# 100 team
# 2 teams
# 3 teamwork
# 1 teas
# 2 teaser
# 3 tech
# 5 technical
# 4 technicians
# 2 techniques
# 2 technologies
# 1 technologists
# 21 technology
# 1 ted
# 1 tedder
# 10 teen
# 6 teens
# 1 tel
# 1 telehealth
# 1 telemedicine
# 12 telephone
# 2 teleradiology
# 1 television
# 4 tell
# 1 temperature
# 8 template
# 2 tempor
# 1 temporary
# 3 ten
# 1 tend
# 1 tenn
# 7 tennessee
# 1 tense
# 1 tenured
# 92 term
# 31 terms
# 26 terrace
# 1 territories
# 1 territory
# 3 terry
# 1 test
# 3 testament
# 1 testifying
# 4 testimonial
# 51 testimonials
# 1 testimonies
# 12 testing
# 1 testosterone
# 4 tests
# 1 tex
# 2 texarkana
# 48 texas
# 1 texashealth
# 7 text
# 1 textsizer
# 19 th
# 2 thai
# 16 thank
# 1 thankful
# 6 thanks
# 4 thcds
# 18 the
# 4 theater
# 1 theaters
# 2 thehearth
# 1 theill
# 1 thelen
# 2 thelma
# 2 theme
# 14 theo
# 7 therapeutic
# 11 therapies
# 12 therapist
# 13 therapists
# 129 therapy
# 1 therapynursing
# 1 thereafter
# 1 therefore
# 1 theresa
# 1 therese
# 1 thermal
# 1 thermometers
# 1 theta
# 1 thevictoriacarecenter
# 1 thevirginian
# 1 thin
# 2 thing
# 16 things
# 4 think
# 11 third
# 1 thirty
# 1 thomson
# 12 thoracic
# 1 thorough
# 5 thorpe
# 2 thoughtfully
# 1 thoughtfulness
# 2 thoughts
# 4 thousands
# 1 threatening
# 41 three
# 1 threshold
# 2 thrift
# 3 thrilled
# 1 thriving
# 8 throat
# 1 thromboembolism
# 16 throughout
# 1 thu
# 3 thunderbird
# 1 thune
# 7 thursday
# 1 thus
# 6 ti
# 1 tica
# 1 tick
# 1 ticket
# 6 tickets
# 1 tide
# 1 tied
# 1 tieman
# 1 tier
# 5 tiffany
# 1 til
# 1 tiled
# 1 timber
# 76 time
# 1 timeless
# 3 timeline
# 2 timeliness
# 2 timely
# 11 times
# 1 tincidunt
# 1 tip
# 18 tips
# 1 tipton
# 1 tire
# 1 tirelessly
# 1 tis
# 2 tissue
# 2 tit
# 3 title
# 1 titleist
# 3 tjc
# 1 tl
# 1 tmh
# 6 tn
# 4 to
# 1 toasted
# 5 tobacco
# 37 today
# 1 todd
# 1 toe
# 19 together
# 12 toggle
# 2 toilet
# 1 tokens
# 1 told
# 1 tolerance
# 10 toll
# 3 tomography
# 2 toni
# 6 took
# 4 tool
# 1 toolbox
# 13 tools
# 94 top
# 2 topic
# 8 topics
# 4 tops
# 1 torch
# 1 tortilla
# 11 total
# 1 totally
# 8 touch
# 1 touching
# 1 tough
# 35 tour
# 1 tourist
# 1 tournament
# 5 tours
# 1 touts
# 3 toward
# 1 towards
# 1 towel
# 1 towels
# 11 tower
# 1 towers
# 14 town
# 7 township
# 4 townships
# 1 toxicology
# 5 toxins
# 1 toy
# 1 tracey
# 1 tracheostomy
# 1 tracked
# 1 tracker
# 2 tract
# 2 tracy
# 1 trademark
# 6 tradition
# 7 traditional
# 3 traditions
# 1 trails
# 14 trained
# 1 trainers
# 24 training
# 1 tranquil
# 1 tranquility
# 6 transfer
# 2 transferring
# 3 transforming
# 1 transfusions
# 1 transgender
# 5 transition
# 1 transitional
# 3 transitions
# 3 translate
# 1 translated
# 1 translational
# 6 transparency
# 2 transparent
# 16 transplant
# 1 transplantation
# 7 transportation
# 15 trauma
# 1 traumatic
# 4 travel
# 1 traveller
# 1 treadmill
# 1 treasure
# 3 treasurer
# 11 treat
# 1 treatable
# 3 treated
# 4 treating
# 66 treatment
# 9 treatments
# 3 treats
# 10 tree
# 1 tremendous
# 1 trend
# 1 trenton
# 2 tressie
# 5 tri
# 1 triad
# 7 trial
# 16 trials
# 2 tribute
# 1 tributes
# 1 tricks
# 1 tries
# 1 trip
# 1 trips
# 1 triscuits
# 5 trophy
# 3 tropical
# 1 trotter
# 9 troy
# 1 truck
# 4 true
# 8 truly
# 5 trust
# 1 trustapp
# 3 trusted
# 4 trustee
# 14 trustees
# 2 truth
# 1 truven
# 2 try
# 1 trying
# 2 tryon
# 1 tsalagi
# 1 tty
# 2 tub
# 1 tube
# 6 tuesday
# 5 tulsa
# 1 tumbler
# 1 tumblers
# 2 tumors
# 1 tunnel
# 3 turkey
# 2 turkish
# 3 turn
# 2 turned
# 10 tv
# 1 tweet
# 3 twelve
# 3 twenty
# 4 twiiter
# 2 twin
# 2 twins
# 26 twitter
# 61 two
# 4 tx
# 7 type
# 6 types
# 3 typically
# 1 ucompare
# 4 ui
# 2 ukrainian
# 2 ul
# 2 ultimate
# 4 ultimately
# 17 ultrasound
# 1 ultrasounds
# 1 umc
# 2 unable
# 2 unadilla
# 1 unassisted
# 1 unavailable
# 5 uncategorized
# 1 uncertain
# 2 unchanged
# 1 uncle
# 2 und
# 1 unde
# 1 under
# 2 undergo
# 1 undergoes
# 1 underserved
# 10 understand
# 1 understandable
# 7 understanding
# 4 understands
# 1 underwear
# 1 unforgettable
# 2 unhs
# 1 uniforms
# 4 uninsured
# 2 union
# 11 unique
# 2 uniquely
# 30 unit
# 23 united
# 4 units
# 1 universe
# 1 universities
# 50 university
# 1 unless
# 1 unlike
# 1 unmanageable
# 3 unmc
# 4 unorganized
# 2 unparalleled
# 1 unplanned
# 1 unsurpassed
# 1 untreated
# 1 unused
# 1 unusual
# 1 unusually
# 4 unwind
# 6 up
# 14 upcoming
# 4 update
# 2 updated
# 8 updates
# 1 upgraded
# 1 upgrades
# 1 upheld
# 1 uplifting
# 4 upon
# 2 upper
# 1 ups
# 1 uptown
# 1 urdu
# 1 ureters
# 1 urethra
# 1 urge
# 36 urgent
# 1 urgently
# 2 urges
# 5 urinary
# 1 url
# 1 urogynecology
# 1 urologic
# 1 urologists
# 31 urology
# 452 us
# 2 usa
# 1 uscommunity
# 1 usd
# 1 usda
# 49 use
# 12 used
# 4 useful
# 3 user
# 4 username
# 3 uses
# 10 using
# 1 usnews
# 2 uspi
# 1 usually
# 9 ut
# 5 utah
# 2 utilities
# 1 utilize
# 2 utmost
# 5 uwai
# 6 va
# 1 vaaler
# 2 vacancy
# 1 vacant
# 1 vaccination
# 1 vacuuming
# 5 valet
# 3 valid
# 1 validated
# 2 validation
# 81 valley
# 17 value
# 3 valued
# 33 values
# 3 valve
# 1 valvular
# 6 van
# 1 vanwhy
# 1 varicocele
# 2 varicose
# 20 variety
# 8 various
# 2 vary
# 1 varying
# 22 vascular
# 1 vasectomy
# 1 vcita
# 2 vegas
# 1 vegetables
# 2 veggies
# 1 vehicle
# 1 vehicles
# 3 vein
# 1 vending
# 9 vendor
# 1 vendors
# 1 venenatis
# 2 venice
# 2 venous
# 2 ventilation
# 2 ventricular
# 1 venture
# 2 verification
# 2 veritas
# 1 verizon
# 5 vermont
# 2 vernon
# 2 version
# 1 versions
# 1 versus
# 2 vestibular
# 1 vestibulum
# 6 veteran
# 5 veterans
# 7 vi
# 1 viborg
# 2 vibrant
# 7 vice
# 1 victims
# 3 victoria
# 1 victorian
# 3 vida
# 30 video
# 12 videos
# 1 vietnam
# 2 vietnamese
# 82 view
# 4 viewpoints
# 4 views
# 1 vigor
# 1 vikings
# 1 vilardo
# 22 villa
# 20 village
# 1 villages
# 14 villas
# 1 vim
# 1 vinaigrette
# 1 vinci
# 1 vine
# 1 violence
# 1 vip
# 25 virginia
# 6 virginian
# 16 virtual
# 1 virtually
# 2 virus
# 48 vision
# 1 visionary
# 1 visions
# 60 visit
# 3 visitation
# 1 visited
# 34 visiting
# 32 visitor
# 80 visitors
# 3 visits
# 3 vista
# 3 vital
# 1 vitality
# 2 vitalstim
# 3 vizient
# 14 vna
# 1 vnas
# 2 vocational
# 1 voice
# 7 volume
# 1 volun
# 2 voluntarily
# 73 volunteer
# 16 volunteering
# 2 volunteerism
# 28 volunteers
# 1 voluptatem
# 6 voted
# 1 voters
# 1 vowed
# 2 vs
# 1 vsp
# 1 vt
# 3 vuksinick
# 8 wa
# 6 wabash
# 1 waged
# 1 wahospitalpricing
# 6 waianae
# 1 waikalua
# 9 wait
# 1 waiting
# 1 waived
# 1 wakarusa
# 4 wake
# 2 waldemere
# 22 walk
# 2 walker
# 1 walkerton
# 7 walking
# 1 wall
# 3 walnut
# 1 walton
# 1 wanigan
# 35 want
# 5 wanted
# 1 warehouse
# 6 warm
# 1 warming
# 3 warmth
# 1 warning
# 1 wars
# 2 warsaw
# 1 wash
# 14 washington
# 2 wasserburger
# 10 watch
# 1 watchdog
# 1 watches
# 1 watching
# 5 water
# 1 watermen
# 1 waterpark
# 1 watson
# 2 watsonville
# 1 wave
# 17 way
# 3 wayne
# 18 ways
# 3 wealth
# 1 wealthy
# 1 weapons
# 1 wear
# 2 weather
# 26 web
# 1 webite
# 1 webmail
# 14 webmaster
# 1 webnursery
# 41 website
# 3 websites
# 1 wecare
# 10 wednesday
# 4 wednesdays
# 1 wee
# 14 week
# 1 weekday
# 2 weekdays
# 1 weekend
# 1 weekends
# 5 weekly
# 2 weeks
# 23 weight
# 41 welcome
# 1 welcomed
# 2 welcomes
# 3 welcoming
# 1 welfare
# 64 well
# 2 wellaware
# 2 wellbeing
# 1 wellcarehealth
# 1 weller
# 2 wellington
# 63 wellness
# 8 wellspring
# 2 welsh
# 3 wendy
# 1 went
# 5 wesley
# 22 wessell
# 24 west
# 1 westbrock
# 1 westbury
# 16 western
# 1 westfall
# 5 westminster
# 1 westnewssudokuanswer
# 4 westover
# 5 westphalia
# 1 westview
# 1 wet
# 1 wetzel
# 1 weymouth
# 3 wgi
# 3 wha
# 4 whatever
# 1 wheat
# 3 wheelchair
# 2 wheels
# 1 whenever
# 1 wherever
# 15 whether
# 1 whidbey
# 5 white
# 8 whitman
# 1 whittington
# 7 whole
# 1 wholeness
# 2 whose
# 10 wi
# 2 wic
# 1 wichita
# 5 wide
# 1 widgets
# 8 wife
# 1 wifi
# 1 wika
# 1 wild
# 1 wildfire
# 1 wildfowl
# 1 wilkes
# 1 will
# 4 william
# 1 williams
# 1 willing
# 1 willingness
# 4 willow
# 3 willowhomecare
# 1 wills
# 2 wilmington
# 1 window
# 1 windows
# 5 wine
# 1 wines
# 1 winfield
# 6 wing
# 9 winner
# 4 winners
# 11 winning
# 2 wins
# 9 winter
# 5 wired
# 2 wireless
# 1 wirt
# 2 wisc
# 23 wisconsin
# 1 wisdom
# 1 wise
# 1 wisely
# 4 wish
# 1 wishlist
# 1 witcik
# 9 within
# 3 without
# 2 wittenberg
# 1 wkow
# 1 wocn
# 1 wolf
# 75 women
# 2 wonder
# 11 wonderful
# 4 woodland
# 5 woods
# 1 woodtick
# 1 wootaek
# 1 worcester
# 2 worchester
# 1 word
# 1 wordpress
# 1 words
# 50 work
# 15 worked
# 3 worker
# 8 workers
# 2 workforce
# 21 working
# 2 workplace
# 7 works
# 1 workschedule
# 1 workshop
# 6 worksite
# 22 world
# 2 worldatwork
# 1 worlds
# 2 worldwide
# 2 worship
# 1 worst
# 2 worth
# 1 worthwhile
# 19 would
# 41 wound
# 2 wounds
# 3 wrap
# 1 wrapped
# 1 wright
# 1 wrist
# 1 write
# 6 wsha
# 2 wsp
# 1 wtc
# 1 wv
# 41 www
# 12 wy
# 5 wyoming
# 1 x4
# 1 yahoo
# 2 yard
# 57 year
# 59 years
# 1 yellow
# 2 yes
# 1 yesenia
# 4 yet
# 2 yiddish
# 3 ynez
# 1 yogurt
# 1 yor
# 7 york
# 6 young
# 1 younger
# 1 youngstown
# 13 youngtown
# 1 yourbloodinstitute
# 1 yourcarecommunity
# 1 yourchristus
# 2 youth
# 13 youtube
# 3 yukon
# 1 yyyy
# 1 zendy
# 2 zero
# 2 zika
# 1 zion
# 5 zip
# 1 zonta
# 2 zoology
# 2 zopim
# 2 zorbaz
# 2 zuhdi

# %% [markdown]
# ### Feed the Bag of Words into a Random Forest Model (supervised learning)
# At this point, we have numeric training features from the Bag of Words and the original CMS MM labels for each feature vector, so let's do some supervised learning!
# Here, we'll use the Random Forest classifier.  The Random Forest algorithm is included in scikit-learn (Random Forest uses many tree-based classifiers to make predictions, hence the "forest").
# Below, we set the number of trees to 100 as a reasonable default value. More trees may (or may not) perform better, but will certainly take longer to run. Likewise, the more features you include for each MM, the longer this will take.

# %%
print ("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 1000 trees
forest = RandomForestClassifier(n_estimators = 10000) 

# Fit the forest to the training set, using the bag of words as 
# features and the MM labels as the response variable

# This may take a few minutes to run
forest = forest.fit( train_data_features, train["page_MM"] )
# Out:
# Training the random forest...

# %% [markdown]
# ### Predict on an out-of-sample dataset
# Next you will run the trained Random Forest on a test dataset and save the results to a file.

# %%
# Note that when we use the Bag of Words for the test set we only call "transform", 
#  not "fit_transform" as we did for the training set. 
# In machine learning, you shouldn't use the test set to fit your model, 
# otherwise you run the risk of overfitting. 
# For this reason, we keep the test set off-limits until we are ready to make predictions.

# Read the test data
test = pd.read_excel("test.xlsx", header=0, delimiter="\t", \
                   quoting=3 )

# Look at the column headers.
test.columns.values
# Out:
# array(['id', 'Provider Type', 'root url', 'scraped url', 'Visible Text',
#        'page_MM'], dtype=object)

# %%
# Verify that there are the expected number of rows and columns
test.shape
# Out:
# (41, 6)

# %%
# Create an empty list and append the clean MMs one by one
num_MM = len(test["Visible Text"])
clean_test_MM = [] 

print ("Cleaning and parsing the test set MMs...\n")
for i in range(0,num_MM):
    if( (i+1) % 10 == 0 ):
        print ("CMS MM %d of %d\n" % (i+1, num_MM))
    clean_MM = MM_to_words( test["Visible Text"][i] )
    clean_test_MM.append( clean_MM )
# Out:
# Cleaning and parsing the test set MMs...
#
# CMS MM 10 of 41
#
# CMS MM 20 of 41
#
# CMS MM 30 of 41
#
# CMS MM 40 of 41

# %%
# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_MM)
test_data_features = test_data_features.toarray()

# %%
# Use the random forest to make CMS MM predictions
result = forest.predict(test_data_features)

# %%
p = forest.predict_proba( test_data_features )
auc = sklearn.metrics.auc( result, p[:,1], reorder=True )
auc
# Out:
# 0.52910000000000001

# %%
outcometest=np.array(test['page_MM'])
expectedtest=outcometest
predicted_test=model.predict(testpredictors)
print(metrics.classification_report(expectedtest, predicted_test))
print(metrics.confusion_matrix(expectedtest, predicted_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-14b6bcae38a9> in <module>()
#       1 outcometest=np.array(test['page_MM'])
#       2 expectedtest=outcometest
# ----> 3 predicted_test=model.predict(testpredictors)
#       4 print(metrics.classification_report(expectedtest, predicted_test))
#       5 print(metrics.confusion_matrix(expectedtest, predicted_test))
#
# NameError: name 'model' is not defined

# %%
# Copy the results to a pandas dataframe with an "PrimaryKey" column and
# a "MMExist" column
output = pd.DataFrame( data={"id":test["id"], "mm_predict":result} )

# Use pandas to write the comma-separated output file
output.to_csv( "results_train-test_100000tree_10000maxfeat_no-numbers_stops-removed.csv", index=False, quoting=3 )

# %% [markdown]
# ### Congratulations, you have run your first supervised learning model!
# You can try different things and see how your results change.
# For example, you can clean the MMs differently,
# choose a different number of vocabulary words for the Bag of Words representation,
# try Porter Stemming, a different classifier, or any number of other things.

# %% [markdown]
# ### Now onto Word Vectors
